# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 1: Using Git and Python for Collaborative Coding in Google Colab & Least Square Application*
# ### (100 Marks)

# %% [markdown]
# ## Preliminary: Certificate of Work
# ### (5 Marks)

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | Nancy | On | Signature | Hours | Contribution |
# | Member 2: | Kimberly | Michl | Signature | Hours | Contribution |
# | Member 3: | Yoda | Yu| Signature | Hours | Contribution |
# | Member 4: | Maswal | Tahir| Signature | 0 | 0%|

# %% [markdown]
# ## Part 1: Printing to the Console
# ### (4 Marks)

# %%
# In the space below, please print "Hello, World! Welcome to the Student Gradebook Management System."
print ("Hello, World! Welcome to the Student Gradebook Management System. ")
# Out:
# Hello, World! Welcome to the Student Gradebook Management System.

# %%
# Fill in your information using the defined variables below:
# (1 mark)
lab_group_number = 10
intake_year = 2025
intake_semester = "Fall" #"Fall" or "Winter"

# Using f-strings and the variables above, print "This is implemented by Group <lab_group_number>, for ENGG680 <intake_semester> of <intake_year>"
# (1 marks)
print(f"This is implemented by Group {lab_group_number}, for ENGG680 {intake_semester} of {intake_year}")
# Out:
# This is implemented by Group 10, for ENGG680 Fall of 2025

# %%
# Similarly, create variables for each of your group members (eg. member_1, member_2....) and assign them your first names.
# Then, using f-strings and the variables above, print the following sentence:
# "Our Group Members include <member_1>, <member_2>, ..."
# (1 marks)
# Fill in your information using the defined variables below:
# (1 mark)
member_1 = "Nancy"
member_2 = "Kimberly"
member_3 = "Yoda"
print(f"Our Group Members include {member_1}, {member_2}, {member_3}")
# Out:
# Our Group Members include Nancy, Kimberly, Yoda

# %%
# Use indexing to print "The subjects involved in this grading system is English and Math." using "subjects" below.
# (1 marks)
subjects = ("English", "Math")
print(f"The subjects involved in this grading system are {subjects[0]} and {subjects[1]}.")
# Out:
# The subjects involved in this grading system are English and Math.

# %% [markdown]
# ## Part 2: Python Fundamentals
# ### (11 Marks)

# %%
# Lists (2 marks)

# 1. Create a list of any 5 cities in Alberta.
#
cities = ["Edmonton", "Calgary", "Red Deer", "Jasper", "Lethbridge"]
# 2. Print the list
#
print(cities)
# 3. Add a new city to list.
#
cities.append("Grande Prairie")
# 4. Remove the second city using either remove() or pop().
#
cities.remove("Calgary")
# 5. Sort the list alphabetically
#
cities.sort()
# 6. Print your final list
#
print(cities)
# Out:
# ['Edmonton', 'Calgary', 'Red Deer', 'Jasper', 'Lethbridge']
# ['Edmonton', 'Grande Prairie', 'Jasper', 'Lethbridge', 'Red Deer']

# %%
# Tuples (2 marks)

# 1. Create a tuple of 3 favorite numbers.
#
numbers = (1, 2, 3)
# 2. Print the tuple.
#
print(numbers)
# 3. Try to modify the second element. Does that work? Explain.
#
numbers[1]=10
# It doesn't work because tuple is immutable.
# Out:
# (1, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[252], line 11
#       8 print(numbers)
#       9 # 3. Try to modify the second element. Does that work? Explain.
#      10 #
# ---> 11 numbers[1]=10
#      12 # It doesn't work because tuple is immutable.
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Dictionaries (2 marks)

# 1. Create a dictionary representing a mini visa form with keys like:
# "Name", "File Number", "Country", "Visa Type", "Expiry Year"
# Assign fictional values to the keys.
# Note: Dictionaries can contain values of different data types.
#
mini_visa={"Name":"Yoda","File Number":123456,"Country":"Taiwan","Visa Type":"Student","Expiry Year":2027}
# 2. Print the dictionary
#
print(mini_visa)
# 3. Add a new key "University" with a value
#
mini_visa["University"]="UoC"
# 4. Update "Expiry Year" to a new year
#
mini_visa["Expiry Year"]=2028
# 5. Print the final dictionary
#
print(mini_visa)
# Out:
# {'Name': 'Yoda', 'File Number': 123456, 'Country': 'Taiwan', 'Visa Type': 'Student', 'Expiry Year': 2027}
# {'Name': 'Yoda', 'File Number': 123456, 'Country': 'Taiwan', 'Visa Type': 'Student', 'Expiry Year': 2028, 'University': 'UoC'}

# %%
# Sets (2 marks)

# Set 1
subjects1 = {"Math", "English", "Physics", "Biology", "History"}

# Set 2
subjects2 = {"Math", "English", "Chemistry", "Geography", "Physics"}

# Tip: Use f-strings to print clear messages along with your output.
# Eg. "Union: ", "Intersection: "

# 1. Print both the sets
#
print(f"Subjects Set 1: {subjects1}")
print(f"Subjects Set 2: {subjects2}")
# 2. Print the union of sets
#
print(f"Union: {subjects1.union(subjects2)}")
# 3. Print the intersection of sets
#
print(f"Intersection: {subjects1.intersection(subjects2)}")
# 4. Print the difference (subjects1 - subjects2)
#
print(f"Difference (subjects1 - subjects2): {subjects1.difference(subjects2)}")
# Out:
# Subjects Set 1: {'History', 'Math', 'Biology', 'Physics', 'English'}
# Subjects Set 2: {'Chemistry', 'Math', 'Physics', 'English', 'Geography'}
# Union: {'Chemistry', 'Biology', 'English', 'History', 'Math', 'Physics', 'Geography'}
# Intersection: {'English', 'Physics', 'Math'}
# Difference (subjects1 - subjects2): {'Biology', 'History'}

# %%
# Classes and Function (3 marks)

# Step 1: Create a class BankAccount.
# Add class attribute bankname="Canada Bank"
# Add 2 instance attributes: account_holder (string) & balance (float, default value 0.0)
class BankAccount:
   bankname = "Canada Bank"
   def __init__(self, account_holder: str, balance: float = 0.0):
        self.account_holder = account_holder
        self.balance = float(balance)
# Step 2: Add methods
# 1. deposit(amount) -> Add amount to the balance
# 2. withdraw(amount) -> Subtract the amount if balance is sufficient, else print an error message
# 3. get_balance() -> Print Account holder's name and current balance
# 4. get_bankname() -> Print the class attribute (staticmethod)
# Note: Use f-strings to display the amount and updated balance whenever you call deposit() or withdraw()
   def deposit(self, amount: float) -> None:
        if amount <= 0:
            print(f"Deposit amount must be positive. Tried: ${amount:.2f}")
            return
        self.balance += amount
        print(f"Deposited ${amount:.2f}. Updated balance: ${self.balance:.2f}")

   def withdraw(self, amount: float) -> None:
        if amount <= 0:
            print(f"Withdraw amount must be positive. Tried: ${amount:.2f}")
            return
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ${amount:.2f}. Updated balance: ${self.balance:.2f}")
        else:
            print(f"Insufficient funds: tried ${amount:.2f}, current balance ${self.balance:.2f}")

   def get_balance(self) -> float:
        print(f"Account holder: {self.account_holder} | Current balance: ${self.balance:.2f}")
        return self.balance

   @staticmethod
   def get_bankname() -> str:
        print(f"Bank name: {BankAccount.bankname}")
        return BankAccount.bankname

# Step 3: Test
# 1. Print the Bankname
BankAccount.get_bankname()
# 2. Create an object of BankAccount with your name and an initial balance of 1000
acct = BankAccount("Yoda", 1000)
# 3. Deposit 500
acct.deposit(500)
# 4. Withdraw 200

# 5. Print the final balance
# Out:
# Bank name: Canada Bank
# Deposited $500.00. Updated balance: $1500.00

# %% [markdown]
# ## Part 3: Using Pandas for Data Management and Analytics
# ### (15 marks)

# %%
# In the space below, please import the Pandas library
#
import pandas as pd

# %%
# Load the student grade CSV files into DataFrames using the defined variables
# (1 marks)
df_english = pd.read_csv('studentGrades_English.csv')
df_math = pd.read_csv('studentGrades_Math.csv')
print(df_english)
print(df_math)
# Out:
#    firstName  lastName  studentID  grade
# 0       Emma     Smith      10959     95
# 1     Sophia  Robinson      75175     88
# 2       Emma    Taylor      42257     87
# 3      David  Robinson      55148     86
# 4    Stephen     Curry      30303     90
# 5   Isabella  Thompson      72824     88
# 6    Jasmine     Smith      70385     84
# 7      James     Jones      87707     76
# 8      Sarah     Swift      61026     80
# 9       Anne     Clark      90449     82
# 10      Ryan    Thomas      62137     92
# 11    Daniel     White      25477     91
# 12      Sara       Doe      47991     98
# 13   Matthew     White      25376     80
#    firstName  lastName  studentID  grade
# 0      James     Jones      87707     92
# 1      Sarah     Swift      61026     98
# 2       Anne     Clark      90449     99
# 3       Ryan    Thomas      62137     89
# 4     Daniel     White      25477     87
# 5       Sara       Doe      47991     86
# 6    Matthew     White      25376     85
# 7       Emma     Smith      10959     90
# 8     Sophia  Robinson      75175     95
# 9       Emma    Taylor      42257     85
# 10     David  Robinson      55148     87
# 11   Stephen     Curry      30303     88
# 12  Isabella  Thompson      72824     79
# 13   Jasmine     Smith      70385     80

# %%
# Print the first 5 rows of df_english using the .head method
#
print(df_english.head())
# Out:
#   firstName  lastName  studentID  grade
# 0      Emma     Smith      10959     95
# 1    Sophia  Robinson      75175     88
# 2      Emma    Taylor      42257     87
# 3     David  Robinson      55148     86
# 4   Stephen     Curry      30303     90

# %%
# Print the first 5 rows of df_math using the .head method
#
print(df_math.head())
# Out:
#   firstName lastName  studentID  grade
# 0     James    Jones      87707     92
# 1     Sarah    Swift      61026     98
# 2      Anne    Clark      90449     99
# 3      Ryan   Thomas      62137     89
# 4    Daniel    White      25477     87

# %%
# Merging the DataFrames on 'studentID'
df_studentGrades = pd.merge(df_english, df_math, on='studentID', suffixes=('_English', '_Math'))
print(df_studentGrades)
# Out:
#    firstName_English lastName_English  studentID  grade_English  \
# 0               Emma            Smith      10959             95
# 1             Sophia         Robinson      75175             88
# 2               Emma           Taylor      42257             87
# 3              David         Robinson      55148             86
# 4            Stephen            Curry      30303             90
# 5           Isabella         Thompson      72824             88
# 6            Jasmine            Smith      70385             84
# 7              James            Jones      87707             76
# 8              Sarah            Swift      61026             80
# 9               Anne            Clark      90449             82
# 10              Ryan           Thomas      62137             92
# 11            Daniel            White      25477             91
# 12              Sara              Doe      47991             98
# 13           Matthew            White      25376             80
#
#    firstName_Math lastName_Math  grade_Math
# 0            Emma         Smith          90
# 1          Sophia      Robinson          95
# 2            Emma        Taylor          85
# 3           David      Robinson          87
# 4         Stephen         Curry          88
# 5        Isabella      Thompson          79
# 6         Jasmine         Smith          80
# 7           James         Jones          92
# 8           Sarah         Swift          98
# 9            Anne         Clark          99
# 10           Ryan        Thomas          89
# 11         Daniel         White          87
# 12           Sara           Doe          86
# 13        Matthew         White          85

# %%
# Take a look at the data contained in the csv files. Why is studentID chosen as the key?
# (0.5 mark)
#studentID is chosen as the key because each ID is unique to the grades associated with it, preventing an issue of duplicate names, such as Emma or Smith, getting confused and having the incorrect grades assigned to them.

# %%
# You will notice that all the column names got suffixes except studentID.
# Explain why pandas didn't add suffixes to the studentID column.
#The studentID column did not recieve a suffix because it was used as the key for the merge, and was common to both files prior to the merge.

# %%
# Let's calculate the average GPA across the two classes for each student
df_studentGrades['GPA'] = df_studentGrades[['grade_English', 'grade_Math']].mean(axis=1)

# Now let's check the data! In the space below, please use the .head method to display the dataframe.
# (1 mark)
print(df_studentGrades.head(14))
# Out:
#    firstName_English lastName_English  studentID  grade_English  \
# 0               Emma            Smith      10959             95
# 1             Sophia         Robinson      75175             88
# 2               Emma           Taylor      42257             87
# 3              David         Robinson      55148             86
# 4            Stephen            Curry      30303             90
# 5           Isabella         Thompson      72824             88
# 6            Jasmine            Smith      70385             84
# 7              James            Jones      87707             76
# 8              Sarah            Swift      61026             80
# 9               Anne            Clark      90449             82
# 10              Ryan           Thomas      62137             92
# 11            Daniel            White      25477             91
# 12              Sara              Doe      47991             98
# 13           Matthew            White      25376             80
#
#    firstName_Math lastName_Math  grade_Math   GPA
# 0            Emma         Smith          90  92.5
# 1          Sophia      Robinson          95  91.5
# 2            Emma        Taylor          85  86.0
# 3           David      Robinson          87  86.5
# 4         Stephen         Curry          88  89.0
# 5        Isabella      Thompson          79  83.5
# 6         Jasmine         Smith          80  82.0
# 7           James         Jones          92  84.0
# 8           Sarah         Swift          98  89.0
# 9            Anne         Clark          99  90.5
# 10           Ryan        Thomas          89  90.5
# 11         Daniel         White          87  89.0
# 12           Sara           Doe          86  92.0
# 13        Matthew         White          85  82.5

# %%
# Do you notice a problem? The rows for first name and last name have been duplicated!
# .drop(columns=['<column_name1>','<column_name2>'] is a Pandas method that can be used to drop columns.
# In the space below, drop the first name and last name associated with the math .csv file.
# (2 mark)
df_studentGrades = df_studentGrades.drop(columns=['firstName_Math', 'lastName_Math'])

# %%
# Let's display the data again. Use an appropriate method (hint: already used before)
# (0.5 mark)
#
print(df_studentGrades)
# Out:
#    firstName_English lastName_English  studentID  grade_English  grade_Math  \
# 0               Emma            Smith      10959             95          90
# 1             Sophia         Robinson      75175             88          95
# 2               Emma           Taylor      42257             87          85
# 3              David         Robinson      55148             86          87
# 4            Stephen            Curry      30303             90          88
# 5           Isabella         Thompson      72824             88          79
# 6            Jasmine            Smith      70385             84          80
# 7              James            Jones      87707             76          92
# 8              Sarah            Swift      61026             80          98
# 9               Anne            Clark      90449             82          99
# 10              Ryan           Thomas      62137             92          89
# 11            Daniel            White      25477             91          87
# 12              Sara              Doe      47991             98          86
# 13           Matthew            White      25376             80          85
#
#      GPA
# 0   92.5
# 1   91.5
# 2   86.0
# 3   86.5
# 4   89.0
# 5   83.5
# 6   82.0
# 7   84.0
# 8   89.0
# 9   90.5
# 10  90.5
# 11  89.0
# 12  92.0
# 13  82.5

# %%
# Let's also rename the first and last names appropriately.
# Complete the code in the space below by replacing "<>" with the proper column name
# (1 mark)

df_studentGrades = df_studentGrades.rename(columns={
    'firstName_English': 'firstName',
    'lastName_English': 'lastName',
    'grade_English': 'englishGrade',
    'grade_Math': 'mathGrade'
    })

# %%
# Now let's find out some statistics about our student grades!
# Please use an appropriate Pandas method in the space below to display statistical values like
# mean, standard deviation, min, max, and others.
# (1 mark)
df_studentGrades.describe()
# Out:
#           studentID  englishGrade  mathGrade       GPA
# count     14.000000     14.000000  14.000000  14.00000
# mean   54086.714286     86.928571  88.571429  87.75000
# std    24610.266586      6.145221   5.918865   3.63609
# min    10959.000000     76.000000  79.000000  82.00000
# 25%    33291.500000     82.500000  85.250000  84.50000
# 50%    58087.000000     87.500000  87.500000  89.00000
# 75%    72214.250000     90.750000  91.500000  90.50000
# max    90449.000000     98.000000  99.000000  92.50000

# %%
# Do you notice a problem?
# Some statistics are not relevant. The average of studentIDs have no meaning in reality!
# Let's typecast each column appropriately so as to only get meaningful statistics.
# In the code below, replace '<>' by choosing between 'str' for string or 'float' for float
# to properly typecast each column.
# (1 marks)
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(str)
df_studentGrades['firstName'] = df_studentGrades['firstName'].astype(str)
df_studentGrades['lastName'] = df_studentGrades['lastName'].astype(str)
df_studentGrades['englishGrade'] = df_studentGrades['englishGrade'].astype(float)
df_studentGrades['mathGrade'] = df_studentGrades['mathGrade'].astype(float)
df_studentGrades['GPA'] = df_studentGrades['GPA'].astype(float)

# %%
# Now let's see our statistics!
df_studentGrades.describe()
# Out:
#        englishGrade  mathGrade       GPA
# count     14.000000  14.000000  14.00000
# mean      86.928571  88.571429  87.75000
# std        6.145221   5.918865   3.63609
# min       76.000000  79.000000  82.00000
# 25%       82.500000  85.250000  84.50000
# 50%       87.500000  87.500000  89.00000
# 75%       90.750000  91.500000  90.50000
# max       98.000000  99.000000  92.50000

# %%
# Now sort the merged dataframe so that it is in descending order based on GPA, and print it
# (1 mark)
df_studentsGPASorted = df_studentGrades.sort_values(by='GPA', ascending=False)
print(df_studentsGPASorted)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 0       Emma     Smith     10959          95.0       90.0  92.5
# 12      Sara       Doe     47991          98.0       86.0  92.0
# 1     Sophia  Robinson     75175          88.0       95.0  91.5
# 9       Anne     Clark     90449          82.0       99.0  90.5
# 10      Ryan    Thomas     62137          92.0       89.0  90.5
# 4    Stephen     Curry     30303          90.0       88.0  89.0
# 11    Daniel     White     25477          91.0       87.0  89.0
# 8      Sarah     Swift     61026          80.0       98.0  89.0
# 3      David  Robinson     55148          86.0       87.0  86.5
# 2       Emma    Taylor     42257          87.0       85.0  86.0
# 7      James     Jones     87707          76.0       92.0  84.0
# 5   Isabella  Thompson     72824          88.0       79.0  83.5
# 13   Matthew     White     25376          80.0       85.0  82.5
# 6    Jasmine     Smith     70385          84.0       80.0  82.0

# %%
# If we wanted to access the student with the highest gpa based on df_studentsGPASorted,
# does .iloc or .loc make more sense and why?
# (2 marks)
# Since students have been sorted in descending order, the sudent with the highest gpa will be in the top row. This means their index will be 0. Since iloc. is better for finding an individual based on index, the iloc. function would be better for directly finding a student based on index[0].

# %%
# Now using the method you specified, assign the variable below to the row containing the student with the highest GPA
# (1 mark)
top_student = df_studentsGPASorted.iloc[0]

# %%
# Now print the student first name and last name with the highest GPA in this format:
# "The student with the highest GPA is <firstName> <lastName> with a GPA of <GPA>"
# (1 mark)
print(f"The student with the highest GPA is {top_student['firstName']} {top_student['lastName']} with a GPA of {top_student['GPA']}")
# Out:
# The student with the highest GPA is Emma Smith with a GPA of 92.5

# %%
# We can use logical expressions to filter and print data. For example, let's print the students with math grades higher than 90:
df_mathGrade_over90 = df_studentsGPASorted[df_studentsGPASorted['mathGrade'] > 90]
print(df_mathGrade_over90)
# Out:
#   firstName  lastName studentID  englishGrade  mathGrade   GPA
# 1    Sophia  Robinson     75175          88.0       95.0  91.5
# 9      Anne     Clark     90449          82.0       99.0  90.5
# 8     Sarah     Swift     61026          80.0       98.0  89.0
# 7     James     Jones     87707          76.0       92.0  84.0

# %%
# Use logical expressions, and print the students with math grades higher than 90, english grades higher than 80, and GPA greater than 85
df_bestStudents = df_studentsGPASorted[(df_studentsGPASorted['mathGrade'] > 90) & (df_studentsGPASorted['englishGrade'] > 80) & (df_studentsGPASorted['GPA'] > 85)]
print(df_bestStudents)
# Out:
#   firstName  lastName studentID  englishGrade  mathGrade   GPA
# 1    Sophia  Robinson     75175          88.0       95.0  91.5
# 9      Anne     Clark     90449          82.0       99.0  90.5

# %%
# Now print the students whos GPA are lower than 85
# (2 marks)
df_poorStudents = df_studentsGPASorted[df_studentsGPASorted['GPA'] < 85]
print(df_poorStudents)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 7      James     Jones     87707          76.0       92.0  84.0
# 5   Isabella  Thompson     72824          88.0       79.0  83.5
# 13   Matthew     White     25376          80.0       85.0  82.5
# 6    Jasmine     Smith     70385          84.0       80.0  82.0

# %%
# Print the Top 3 Performers (highest GPA)
print(df_studentsGPASorted.head(3))
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 0       Emma     Smith     10959          95.0       90.0  92.5
# 12      Sara       Doe     47991          98.0       86.0  92.0
# 1     Sophia  Robinson     75175          88.0       95.0  91.5

# %%
# Print the Bottom 2 Performers (lowest GPA)
print(df_studentsGPASorted.tail(2))
# Out:
#    firstName lastName studentID  englishGrade  mathGrade   GPA
# 13   Matthew    White     25376          80.0       85.0  82.5
# 6    Jasmine    Smith     70385          84.0       80.0  82.0

# %% [markdown]
# ## Part 4: More Data Analytics using Pandas
# ### (18 marks)

# %%
# Select the column 'grade' from the original English grade dataset and print it
print(df_english['grade'])
# Out:
# 0     95
# 1     88
# 2     87
# 3     86
# 4     90
# 5     88
# 6     84
# 7     76
# 8     80
# 9     82
# 10    92
# 11    91
# 12    98
# 13    80
# Name: grade, dtype: int64

# %%
# Select the column 'GPA' from the df_studentGrades and print it
print(df_studentGrades['GPA'])
# Out:
# 0     92.5
# 1     91.5
# 2     86.0
# 3     86.5
# 4     89.0
# 5     83.5
# 6     82.0
# 7     84.0
# 8     89.0
# 9     90.5
# 10    90.5
# 11    89.0
# 12    92.0
# 13    82.5
# Name: GPA, dtype: float64

# %%
# What is the data type of grade from the English grade dataset?
# (0.5 mark)
# integer

# What is the data type of GPA from the merged dataset?
# (0.5 mark)
# float

# Is it different? Why?
# (1 mark)
#Yes. It is different because interger data type are whole numbers and do not have decimal points, where as float data type are fractional numbers that have decimal points.

# %%
# Load the student homeroom CSV file into a DataFrame using the following variable name
# (1 mark)
df_homeroom = pd.read_csv('studentHomerooms.csv')

# %%
# Print first 5 rows of df_homeroom using the .head method
print(df_homeroom.head())
# Out:
#   firstName  lastName  studentID  homeRoom
# 0      Emma     Smith      10959       313
# 1    Sophia  Robinson      75175       311
# 2      Emma    Taylor      42257       311
# 3     David  Robinson      55148       313
# 4   Stephen     Curry      30303       313

# %%
# Merge the studentHomerooms with the merged dataset & name it df_studentInfo. Make sure that the key you are joining on are the same typecast for both datasets.
# Also ensure that there are no redundant columns, and finally display the first few rows.
# Hint: try joining on more than one column to avoid having to drop redundant columns, ie. on=['studentID', '<ColumnA>', '<ColumnB>'] ...
# (5 marks)
df_homeroom['studentID'] = df_homeroom['studentID'].astype(str)
df_studentInfo = pd.merge(df_studentGrades, df_homeroom, on=['studentID', 'firstName', 'lastName'])
print(df_studentInfo)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA  homeRoom
# 0       Emma     Smith     10959          95.0       90.0  92.5       313
# 1     Sophia  Robinson     75175          88.0       95.0  91.5       311
# 2       Emma    Taylor     42257          87.0       85.0  86.0       311
# 3      David  Robinson     55148          86.0       87.0  86.5       313
# 4    Stephen     Curry     30303          90.0       88.0  89.0       313
# 5   Isabella  Thompson     72824          88.0       79.0  83.5       311
# 6    Jasmine     Smith     70385          84.0       80.0  82.0       313
# 7      James     Jones     87707          76.0       92.0  84.0       313
# 8      Sarah     Swift     61026          80.0       98.0  89.0       311
# 9       Anne     Clark     90449          82.0       99.0  90.5       311
# 10      Ryan    Thomas     62137          92.0       89.0  90.5       313
# 11    Daniel     White     25477          91.0       87.0  89.0       311
# 12      Sara       Doe     47991          98.0       86.0  92.0       311
# 13   Matthew     White     25376          80.0       85.0  82.5       313

# %%
# The code below calculates the mean of each homeroom class.
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()
print(df_grouped)

# Which homeroom has a higher GPA?
# (1 mark)
#homeRoom 311 has a higher mean GPA of 88.8 where as homeRoom 313 only hav a mean GPA of 86.7
# Out:
# homeRoom
# 311    88.785714
# 313    86.714286
# Name: GPA, dtype: float64

# %%
# Now let's work with multiple sorts. The .sort_values() method can sort by multiple columns, meaning you can specify a primary column and a secondary column for sorting.
# For example, by=['ColumnA', 'ColumnB'] will first sort by ColumnA and then by ColumnB.
# Create and print a DataFrame, df_studentsGPASorted_homeroom, which is sorted by homeRoom and then by GPA, both in descending order.
# (3 mark)
df_studentsGPASorted_homeroom = df_studentInfo.sort_values(by=['homeRoom', 'GPA'], ascending=False)
print(df_studentsGPASorted_homeroom)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA  homeRoom
# 0       Emma     Smith     10959          95.0       90.0  92.5       313
# 10      Ryan    Thomas     62137          92.0       89.0  90.5       313
# 4    Stephen     Curry     30303          90.0       88.0  89.0       313
# 3      David  Robinson     55148          86.0       87.0  86.5       313
# 7      James     Jones     87707          76.0       92.0  84.0       313
# 13   Matthew     White     25376          80.0       85.0  82.5       313
# 6    Jasmine     Smith     70385          84.0       80.0  82.0       313
# 12      Sara       Doe     47991          98.0       86.0  92.0       311
# 1     Sophia  Robinson     75175          88.0       95.0  91.5       311
# 9       Anne     Clark     90449          82.0       99.0  90.5       311
# 8      Sarah     Swift     61026          80.0       98.0  89.0       311
# 11    Daniel     White     25477          91.0       87.0  89.0       311
# 2       Emma    Taylor     42257          87.0       85.0  86.0       311
# 5   Isabella  Thompson     72824          88.0       79.0  83.5       311

# %%
# Do you notice a problem with the indices? They are basically meaningless now that we have sorted by homeroom and GPA.

# The code below changes the index of the dataframe so that it is more intuitive.
df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])

print(df_studentsGPASorted_homeroom)
# Out:
#          firstName  lastName studentID  englishGrade  mathGrade   GPA  \
# newIndex
# 313-1         Emma     Smith     10959          95.0       90.0  92.5
# 313-2         Ryan    Thomas     62137          92.0       89.0  90.5
# 313-3      Stephen     Curry     30303          90.0       88.0  89.0
# 313-4        David  Robinson     55148          86.0       87.0  86.5
# 313-5        James     Jones     87707          76.0       92.0  84.0
# 313-6      Matthew     White     25376          80.0       85.0  82.5
# 313-7      Jasmine     Smith     70385          84.0       80.0  82.0
# 311-1         Sara       Doe     47991          98.0       86.0  92.0
# 311-2       Sophia  Robinson     75175          88.0       95.0  91.5
# 311-3         Anne     Clark     90449          82.0       99.0  90.5
# 311-4        Sarah     Swift     61026          80.0       98.0  89.0
# 311-5       Daniel     White     25477          91.0       87.0  89.0
# 311-6         Emma    Taylor     42257          87.0       85.0  86.0
# 311-7     Isabella  Thompson     72824          88.0       79.0  83.5
#
#           homeRoom
# newIndex
# 313-1          313
# 313-2          313
# 313-3          313
# 313-4          313
# 313-5          313
# 313-6          313
# 313-7          313
# 311-1          311
# 311-2          311
# 311-3          311
# 311-4          311
# 311-5          311
# 311-6          311
# 311-7          311

# %%
# Describe what each coding line in the cell above is doing
# (4 marks)
#The cell above is modifying the index of the df_studentsGPASorted_homeroom to first sort the students by their home room, and then within the span of each homeroom ranking the students according to their GPA in descending order.This provides a more intuitive way of sorthing that makes it easier to visualize each student with their homeroom and relative GPA.

# %%
# Given df_studentsGPASorted_homeroom, please find and print the students with the highest GPA in each homeroom using the .loc method.
# (2 marks)
print(df_studentsGPASorted_homeroom.loc[df_studentsGPASorted_homeroom.groupby('homeRoom')['GPA'].idxmax()])
# Out:
#          firstName lastName studentID  englishGrade  mathGrade   GPA  homeRoom
# newIndex
# 311-1         Sara      Doe     47991          98.0       86.0  92.0       311
# 313-1         Emma    Smith     10959          95.0       90.0  92.5       313

# %% [markdown]
# ## Part 5: Using Matplotlib for Data Analytics
# ### (12 marks)

# %%
# In the space below, please import the matplotlib library
#
import matplotlib.pyplot as plt
import numpy as np

# %%
# Let's use matplotlib to display a histogram of the grades distribution
# Histograms are useful for seeing the distribution of the students grades

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['englishGrade'], bins=10, alpha=0.7, label='English Grades', color='blue')

# Step 1: Use the line above as reference to create a histogram for the math grades
# (1 mark)
#
plt.hist(df_studentGrades['mathGrade'], bins=10, alpha=0.7, label='Math Grades')

# Step 2: Ensure that your plot is descriptive, so use labels (x and y axis), a title, and a legend.
# Hint: Use the matplotlib .legend(loc='<location>') to add and place the legend.
# You can use 'upper left', 'upper right', 'lower left', and 'lower right' to specify the location.
# (3 marks)
#
plt.xlabel('Grade')
plt.ylabel('Number of Students')
plt.title('Distribution of English and Math Grades')
plt.legend(loc='upper right')
plt.grid(True)

# Step 3: Use the .savefig('<image_title>'.png) to output an image file of the histogram.
# Please be sure to use a descriptive title!
# (1 mark)
#
plt.tight_layout()
plt.savefig("distribution_english_math_grades_histogram.png")
plt.show()

# %%
# Let's also use matplotlib to display a scatter plot of English vs. Math grades
# Scatter plots are useful for seeing the relationship between two variables
plt.figure(figsize=(10, 6))

# Step 1: Use .scatter(x_data, y_data) to create a scatter plot using the English grades on the x-axis, and Math grades on the y-axis
# (2 mark)
#
plt.scatter(df_studentGrades['englishGrade'], df_studentGrades['mathGrade'])
# Step 1: Properly label the x and y axes as well as the title of your plot.
# (3 marks)
#
plt.xlabel('English Grade')
plt.ylabel('Math Grade')
plt.title('English vs. Math Grades (Scatter Plot)')
plt.grid(True)

# Step 2: Output an image file for the scatter plot with a descriptive file name
# (1 mark)
#
plt.tight_layout()
plt.savefig("english_vs_math_grades_scatter.png")
plt.show()

# %%
# From the scatter plot, is there a relationship between the Math and English grades?
# (1 mark)
# Yes,there’s a positive relationship (moderate to strong.) But it isn’t perfect (some spread.)

# %% [markdown]
# ## Part 6: Linear LSE
# ### (35 marks)

# %% [markdown]
# ### Curve Fitting

# %% [markdown]
# ![curvefitting.png](data:image/png;base64,...)

# %% [markdown]
# ### Observations: values of a function f(a) in range of -π to π, contaminated with random noise

# %% [markdown]
# ### Unknown States: coefficients of polynomial functions for curve fitting

# %%
# step 1
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# step 2
# Load data.xlsx file, which contains the observations (with noise), variance of observations and true observations
# hint: use pandas library to parse excel file and use numpy library to convert it to array
# (1 mark)
df_data = pd.read_excel('data.xlsx')
arr_data = df_data.to_numpy()

#store the noisy observations, variance of observations and true observations into numpy arrays seperately
# (1 mark)
l = arr_data[:,0]
l_var = arr_data[:,1]
l_true = arr_data[:,2]

# %%
# step 3
# define the number of observation n
# (1 mark)
n = len(l)


# define the observation weight matrix P for LSE as identity matrix
# identity weight matrix simply means the observations will be unweighted in the following LSE
# (1 mark)
P = np.identity(n)

# define the range of function input(i.e., constants a), from start to end; and the numerical array of a
start = -1* np.pi
end = np.pi
a = np.linspace(start, end, n)

# %%
# step 4
# use the matplotlib to plot the true and noisy observations together in one single figure
# use scatter for noisy observation plotting
# for the true observation, label it as "f(a)"" and set color as 'k'
# for the noisy observation scatter plot, label it as "f(a) + e", set color as 'tab:blue', set marker as 'o' and set alpha as 0.3
# include proper axis labels, legend and title
# scale the range of x-axis to be -1 to 1
# keep this format for the rest of the plots in this lab assignment
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

#creating plots for true and noisy observations
ax.plot (a, l_true, label='f(a)', color= 'k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o',alpha =0.3)

#Adding labels and adjusting axes
ax.set_xlabel ("a")
ax.set_ylabel ("Observations")
ax.set_title ("Plot of True and Noisy Observations")
ax.legend (loc='best')
ax.set_xlim (-1,1)


ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()

# %%
# step 5
# define a curve fitting function named fit_polynomial_curve
# the function should implement the linear least square estimation
# the function should include all important intermediate steps in LSE
# the input and output of the funciton are described in the comment below in red.
# please keep code clean and well-commented
# (7 marks)

def fit_polynomial_curve(a: np.ndarray, l: np.ndarray, P: np.ndarray, deg: int) -> tuple:
    '''
    Args:
        a:              function input (constants)
        l:              noisy observations
        P:              observation weight matrix
        deg:            degree of polynomial to fit to data
    Returns:
        x:              estimated polynomial coefficients
        cov_x:          uncertainty in estimated coefficients
        apv:            a posterier variance factor (goodness of fit)
        v:              observation residuals
    '''

    #defining general matrix A for polynomial
    A = np.vander(a, N= deg + 1, increasing = True)

    #computing normal matrix A^TPA and A^TPl
    ATPA = A.T @ P @ A
    ATPl = A.T @ P @ l

    #solving system of normal equations
    x= np.linalg.solve(ATPA, ATPl)

    #Finding the equation for the line of best-fit
    y=np.poly1d(x[::-1])

    #Computing vector of residuals
    v = l - (A @ x)

    #Computing posterior variance factor
    degrees_of_freedom = n-(deg+1)
    apv = (v.T @ P @ v)/ degrees_of_freedom

    #Computing the covariance of estimated coefficients
    cov_x = apv * np.linalg.inv(ATPA)

    return (x, cov_x, apv, v)

# %%
# step 6
# call the fit_polynomial_curve function and fetch the results
# use polynomial degrees of: 2, 4, 6
# (1 marks)

degree = [2,4,6]
results = {}

for deg in degree:
    x, cov_x, apv, v = fit_polynomial_curve(a, l, P, deg)
    results[deg]= {'x':x,
                   'cov_x' : cov_x,
                   'apv': apv,
                   'v':v }

    print(f"Results for polynomial with degree {deg}:")
    print(f"Estimated polynomial coefficients: {results[deg]['x']}")
    print(f"Uncertainty in estimated coefficients: {results[deg]['cov_x']}")
    print(f"Posterior variance factor: {results[deg]['apv']}")
    print(f"Observation residuals: {results[deg]['v']}\n")
# Out:
# Results for polynomial with degree 2:
# Estimated polynomial coefficients: [-16.72496774   7.25633807   0.03979476]
# Uncertainty in estimated coefficients: [[ 7.33757581e-01 -4.27093762e-17 -1.23414657e-01]
#  [-4.27093762e-17  9.87305411e-02  1.63284462e-17]
#  [-1.23414657e-01  1.63284462e-17  3.73638027e-02]]
# Posterior variance factor: 163.0561531810196
# Observation residuals: [ 22.93377858  23.10429728   0.26160792  23.09565871  19.42101691
#   23.52242975  23.10271832  21.59356789  20.89900961   5.38009705
#   22.24517761  13.11326098  23.17697846  22.18196599  11.13480557
#   25.14949476  14.20767999   8.3112389   17.71806825   1.91474394
#   14.40639756   9.50875064  12.88667842  16.12442553  11.37942053
#   11.45179063   5.89382453  32.28848088  14.10983247  13.99264594
#   17.14413109   7.66557819  17.15457029  13.38796861  -6.03557984
#   -2.20227819   8.29985362  -7.32816076   6.98591686   4.79115352
#    7.39140975  12.79448295   6.41293027   5.56117938  10.01649315
#    4.40712691  14.7453685    9.59455565   5.19814429   5.254977
#   32.74384697  10.43373054  27.71265027   9.05270973  -0.05824075
#    0.21262348 -19.84111623   6.7079856    4.62897182  -2.19979223
#   -2.89097579   2.2318098  -11.5327606  -12.57678479   7.29572414
#    0.95219631  -1.26805375 -24.68254128  10.65982129  -7.71124059
#    1.89608498   2.19936052  -9.63954254  -5.49436983  16.04454932
#   -3.40900786  -7.00688262  -3.50188018  -8.06302337  -3.44506844
#   -4.79277826   4.09904356  -6.44961428 -16.63409401  -6.76044187
#   -7.01469617  -6.59636961  -0.96817164  -2.78527295  -2.88273311
#  -14.81031765  -4.96224161  -2.74903492 -10.68783957  -8.76296102
#  -21.71407088  -1.55993616  -9.1757256   -0.21947381  -7.23227044
#  -11.24088881 -15.19633658 -25.97763442 -32.50611113 -16.64786511
#   -0.38347922 -10.94348388 -28.23108936  -3.22437021  -0.65661453
#   -6.38338307  -6.35540309 -11.46502314 -25.02356804 -18.05360897
#  -14.0945213  -14.60950754 -11.63073222  -7.96884498 -16.05332995
#    0.38854865 -16.21503487  -9.63783941 -10.60314232 -12.77828557
#  -11.78944557 -15.60686283 -10.81022138  -9.97331668 -12.41102306
#  -17.57031488 -15.83581708  -9.05549525  -9.80606171 -28.01555848
#   -2.67882277 -29.53017965  -2.51063698  -8.719336   -10.78826614
#  -14.4310768  -11.22869233   1.0074266  -10.64183107 -22.41703042
#  -11.18044527 -11.93550718   2.31440125 -13.2927511  -11.37654526
#   -8.55569749 -13.9038815    6.5169646  -25.85911215  -4.16564867
#   -9.69017577 -12.52934474  17.55499841 -14.7886712  -17.07745233
#  -11.58800063 -12.12191488  -5.15210374 -12.33495824 -11.48918471
#    8.20201474 -17.67214777 -14.04169521  -2.96423106 -14.63650585
#  -16.40873251  -6.7839674    1.07814484 -12.9106601  -13.64738994
#  -14.64147559 -15.81613457  -1.04718629 -11.63306005 -14.11925198
#   -8.19984754   0.04908367 -11.97667121 -29.91326692  19.46344635
#  -19.37192872 -15.65805875  -9.48540501 -11.03544451 -11.46933952
#   -3.02622319 -17.57761262 -16.61181124 -10.01704912 -14.06211754
#   -9.4995005   -6.56607724 -30.77564982  -5.65652936 -11.82760051
#  -20.44459024  -8.00568423  -8.47128324  -7.55365613  -7.2394014
#    3.13588513 -12.980641    -7.56495435 -14.66168228  -6.83542761
#   -8.10656072  -9.68706838  -8.35840613  -1.99614987 -10.19615344
#   -9.50979205  -6.6784725  -15.89319726  -5.87341913  -6.31501361
#  -14.3559472  -18.83238649 -21.31585437 -22.48050546  -5.03606377
#   -3.14936889  -2.4154134  -11.65301205  -4.53748458  -1.09787912
#  -15.49880306  -3.40294017  -0.42279461 -10.38417026   5.17709397
#   -8.73671847 -11.5341911    5.05672201   9.65579515  -1.32412346
#    2.29205642  -3.48195866 -10.4502524    0.43344826   3.17734499
#   -4.02981875   5.34195363  -4.6950251   -9.59323904   9.17163491
#   13.67360293  -3.78377517  20.84660753  -2.16556779   1.71838722
#    0.47519821   5.20122356   4.19380096   2.43667941  -0.43802842
#  -15.08871202  14.55599443  -2.7219957    2.1360514    3.88198438
#    6.02570372   3.12121841  -1.19150153  -0.32293747   3.30747928
#    1.90173892   4.13937891   3.52307342  10.8472827    3.79717476
#   -8.82174409  18.1997536   14.58185485  26.01707355  -8.51547846
#    3.7751862   15.16747803  10.72802187   7.60836335 -15.75076266
#   -2.1467304    9.61904059  15.22755136   6.59618196  16.81264837
#   -2.99085384   3.42926869  -1.25870106   6.86589232  10.03825868
#    5.4355217   28.330685    10.62174172  21.48203841  13.02140059
#   24.53952119   1.08191789  10.47853859   9.44891857  15.34651962
#    3.67275793  11.36531277  10.99270223   5.47454352  11.80909447
#   20.82631605   9.46907285  11.24067412   1.3704347   37.92097088
#   20.80370813  14.15716094  18.8719533   14.81090761  19.72180484
#    9.86347022  -0.14422602  13.95125161  10.59469838  10.32896012
#   12.78067543   9.90792513  26.04191793   6.9888593   10.84623554
#   13.00049601  14.70782545   4.57882584  13.30718246  15.03058891
#    9.24318014  17.54047425  10.499247    10.86698857  14.44800705
#   12.95623981  29.08593657  15.32608453  25.68158249  -6.39301975
#   10.66179232   3.73305259   6.31838082   0.33277788  14.26361081
#   14.67780428  13.68984038   9.0274646   12.05807816   5.6143678
#   17.02242409   8.83697959  10.15239845  14.49864243   3.60292884
#   14.95796554  21.71605103  13.61077879  19.25586875   1.62215083
#    9.35758873  12.61051413  -0.82929902  14.64509971  23.32543436
#  -12.8437719    0.80963457  12.90691452  15.94606594  20.10863474
#   12.26670748  11.52180856  12.76608276   7.12416664   5.87711399
#    8.27457034  11.11633788   5.1322514    5.55027423  10.54634983
#   11.5958102    9.14298242   4.52353219   9.5844891    2.67070158
#   13.24465603   6.99928531   0.03867469   8.16864854  11.22432708
#   15.45565863   9.00665673   1.5431277   12.86159045   0.97858108
#   15.10295764   3.54106898  15.62978517  17.51554333  12.04807002
#   15.7322464    5.27634485   2.34417159   6.59196234   4.12476096
#   17.94260233  -2.55332813  12.17581341   9.58841223   7.92104182
#   16.30789803   4.8283529   -2.35784923   7.24846299   2.76834417
#    6.27102862  12.7553969    1.02448474  10.85114109   1.45722292
#    7.72407086   3.54040817   5.45990904   0.92684826  -4.50593165
#   -1.56256427   9.69837643  -0.84333567  -8.89594018  -1.31842591
#    0.1020682  -13.34142777  -8.20976998  -4.87419412 -16.21157754
#   -8.38322857  -7.78124928 -14.82348841   1.10339489   9.78029151
#    7.59650886   1.40940708   2.5166844    7.44731737  -3.76957312
#    1.7373707    7.73332057  -5.83393625   8.45165718 -13.41820943
#  -10.54821564  -5.997879    -5.8022805  -16.30541765  -3.77828002
#   -8.25119331 -14.60453711  -8.73408188  -9.74313687  -8.28679447
#  -21.86542836   3.14369117  -4.68337325   1.44412627 -11.17510587
#  -11.85291811 -16.34561976  -5.7512026  -12.60795891 -14.90492137
#   -5.70680126  -2.0771996  -14.24925432 -13.27916692 -18.94049831
#   -0.0591513  -27.38235966 -26.14403229 -16.79034276 -13.27154544
#  -11.42504305 -18.49816048 -14.23081431 -24.31701459 -28.26313996
#  -28.40063675  -9.12567166 -13.57712774 -20.79208729 -18.16392923
#   -3.10827789 -23.8437616  -29.26642688 -14.38257904 -23.10057115]
#
# Results for polynomial with degree 4:
# Estimated polynomial coefficients: [-1.65770980e+01  1.96396137e+01 -1.09433276e-01 -2.08281013e+00
#   1.75697706e-02]
# Uncertainty in estimated coefficients: [[ 4.65817956e-01  2.83150143e-16 -2.19380903e-01 -4.17117844e-17
#    1.99257569e-02]
#  [ 5.93225481e-16  2.50716018e-01 -5.89817390e-16 -3.54223870e-02
#    6.79874965e-17]
#  [-2.19380903e-01 -2.76893727e-16  1.85973731e-01  3.95958304e-17
#   -2.01087933e-02]
#  [-9.38650329e-17 -3.54223870e-02  9.22281543e-17  5.95788291e-03
#   -1.05238094e-17]
#  [ 1.99257569e-02  3.11445750e-17 -2.01087933e-02 -4.32699913e-18
#    2.36756365e-03]]
# Posterior variance factor: 66.24842817291719
# Observation residuals: [-3.12970406e+00 -2.32621177e+00 -2.45424071e+01 -1.08831435e+00
#  -4.14933859e+00  5.59294919e-01  7.40434817e-01 -1.74206079e-01
#  -2.80569116e-01 -1.52175732e+01  2.22315658e+00 -6.33934260e+00
#   4.28758802e+00  3.84961188e+00 -6.64666157e+00  7.91279269e+00
#  -2.49035149e+00 -7.85418903e+00  2.07920425e+00 -1.32035684e+01
#  -1.97347855e-01 -4.58638532e+00 -7.05778144e-01  3.02874566e+00
#  -1.22535798e+00 -6.67934512e-01 -5.74666791e+00  2.11214278e+01
#   3.41045272e+00  3.75520080e+00  7.36290912e+00 -1.66510477e+00
#   8.26876946e+00  4.94142028e+00 -1.40484781e+01 -9.78710142e+00
#   1.13755745e+00 -1.40734506e+01  6.52139929e-01 -1.13657683e+00
#   1.86428686e+00  7.66255559e+00  1.67081366e+00  1.20351590e+00
#   6.03795233e+00  8.02405391e-01  1.15091901e+01  6.72167117e+00
#   2.68333176e+00  3.09304149e+00  3.09296206e+01  8.96207259e+00
#   2.65784470e+01  8.25087446e+00 -5.32767666e-01  6.03723093e-02
#  -1.96760973e+01  7.18529613e+00  5.41362229e+00 -1.11272641e+00
#  -1.50639229e+00  3.90904032e+00 -9.56772680e+00 -1.03287645e+01
#   9.82194107e+00  3.75184694e+00  1.80029454e+00 -2.13502044e+01
#   1.42514644e+01 -3.86494655e+00  5.99240145e+00  6.54109778e+00
#  -5.05695930e+00 -6.75488567e-01  2.10952075e+01  1.86893286e+00
#  -1.50612687e+00  2.21724988e+00 -2.12993294e+00  2.69759518e+00
#   1.55509814e+00  1.06477991e+01  2.95713402e-01 -9.69647434e+00
#   3.65216316e-01  2.94773749e-01  8.92711976e-01  6.69634823e+00
#   5.05053849e+00  5.12024985e+00 -6.64425655e+00  3.36283088e+00
#   5.73100884e+00 -2.05683803e+00  1.50114282e-02 -1.27930878e+01
#   7.50012387e+00  1.95042737e-02  9.10704537e+00  2.22168407e+00
#  -1.66332638e+00 -5.49896714e+00 -1.61642323e+01 -2.25804242e+01
#  -6.61361471e+00  9.75563982e+00 -7.03164558e-01 -1.78932116e+01
#   7.20745049e+00  9.86556019e+00  4.22558314e+00  4.33681853e+00
#  -6.93055782e-01 -1.41753382e+01 -7.13257351e+00 -3.10411068e+00
#  -3.55312585e+00 -5.11757172e-01  3.20937205e+00 -4.81919594e+00
#   1.16753010e+01 -4.87893662e+00  1.74435876e+00  8.21936032e-01
#  -1.31352047e+00 -2.88160889e-01 -4.07219943e+00  7.54706117e-01
#   1.61878654e+00 -7.94806222e-01 -5.93302033e+00 -4.18045449e+00
#   2.61495193e+00  1.87651278e+00 -1.63237878e+01  9.01923930e+00
#  -1.78287050e+01  9.19139774e+00  2.98043232e+00  9.06435504e-01
#  -2.74421601e+00  4.47579558e-01  1.26703876e+01  1.00512324e+00
#  -1.07887526e+01  4.26512355e-01 -3.52487386e-01  1.38708916e+01
#  -1.76535572e+00  1.19215627e-01  2.90591539e+00 -2.47890412e+00
#   1.79028450e+01 -1.45147643e+01  7.13475716e+00  1.56390444e+00
#  -1.32394776e+00  2.87093805e+01 -3.68760974e+00 -6.03199133e+00
#  -6.00393962e-01 -1.19439055e+00  5.71313614e+00 -1.53417903e+00
#  -7.55016522e-01  1.88674474e+01 -7.07754927e+00 -3.52000367e+00
#   7.48250652e+00 -4.26674338e+00 -6.11794050e+00  3.42588458e+00
#   1.12051130e+01 -2.86849370e+00 -3.69191758e+00 -4.77456373e+00
#  -6.03962396e+00  8.63710807e+00 -2.04277121e+00 -4.62473225e+00
#   1.19716522e+00  9.34687729e+00 -2.77978324e+00 -2.08189454e+01
#   2.84535662e+01 -1.04876201e+01 -6.88114517e+00 -8.17444758e-01
#  -2.47797024e+00 -3.02385826e+00  5.30578361e+00 -9.36053614e+00
#  -8.51109537e+00 -2.03409858e+00 -6.19831151e+00 -1.75619261e+00
#   1.05540442e+00 -2.32772970e+01  1.71741760e+00 -4.57931100e+00
#  -1.33231843e+01 -1.01236239e+00 -1.60722068e+00 -8.20002516e-01
#  -6.37280958e-01  9.60537359e+00 -6.64485789e+00 -1.36392454e+00
#  -8.59642833e+00 -9.06946670e-01 -2.31582456e+00 -4.03502342e+00
#  -2.84597341e+00  3.37577493e+00 -4.96560692e+00 -4.42146883e+00
#  -1.73319228e+00 -1.10917544e+01 -1.21658279e+00 -1.80352757e+00
#  -9.99052999e+00 -1.46137314e+01 -1.72446294e+01 -1.85573533e+01
#  -1.26160203e+00  4.75810148e-01  1.05991585e+00 -8.32807449e+00
#  -1.36345541e+00  1.92475014e+00 -1.26280400e+01 -6.84484596e-01
#   2.14293750e+00 -7.97155253e+00  7.43623156e+00 -6.63140167e+00
#  -9.58301064e+00  6.85347569e+00  1.12978567e+01  1.63005638e-01
#   3.62403786e+00 -2.30531504e+00 -9.42911172e+00  1.29894590e+00
#   3.88708452e+00 -3.47592738e+00  5.73993178e+00 -4.45300023e+00
#  -9.50718254e+00  9.10173292e+00  1.34477773e+01 -4.16546465e+00
#   2.03091389e+01 -2.85870585e+00  8.69714259e-01 -5.28850164e-01
#   4.04198415e+00  2.87957977e+00  9.67710564e-01 -2.06148592e+00
#  -1.68663743e+01  1.26244360e+01 -4.80711673e+00 -1.02273891e-01
#   1.49083799e+00  3.48214418e+00  4.25678461e-01 -4.03856436e+00
#  -3.32104090e+00  1.58842302e-01 -1.39689982e+00  6.91294938e-01
#  -7.38745244e-02  7.10207675e+00 -9.56585214e-02 -1.28615493e+01
#   1.40136564e+01  1.02501705e+01  2.15405314e+01 -1.31361244e+01
#  -9.88784808e-01  1.02609852e+01  5.67983522e+00  2.41933538e+00
#  -2.10797548e+01 -7.61478501e+00  4.01284982e+00  9.48417529e+00
#   7.16596028e-01  1.07978525e+01 -9.13983508e+00 -2.85284893e+00
#  -7.67288151e+00  3.20747077e-01  3.36327118e+00 -1.36816104e+00
#   2.13994785e+01  3.56420743e+00  1.42993967e+01  5.71489634e+00
#   1.71104236e+01 -6.46847926e+00  2.80815992e+00  1.65990087e+00
#   7.44022978e+00 -4.34941281e+00  3.22867676e+00  2.74304091e+00
#  -2.88667879e+00  3.33779982e+00  1.22464620e+01  7.82196747e-01
#   2.44833752e+00 -7.52577652e+00  2.89224952e+01  1.17046024e+01
#   4.95908388e+00  9.57658782e+00  5.41996090e+00  1.02370083e+01
#   2.86579444e-01 -9.81143119e+00  4.19553606e+00  7.52300660e-01
#   4.01732599e-01  2.77049466e+00 -1.83308198e-01  1.58715569e+01
#  -3.25868049e+00  5.23490095e-01  2.60454210e+00  4.24068440e+00
#  -5.95745698e+00  2.70382736e+00  4.36225506e+00 -1.48801486e+00
#   6.74855975e+00 -3.51221333e-01 -3.98438734e-02  3.48702421e+00
#   1.94334430e+00  1.80233901e+01  4.21617283e+00  1.45266152e+01
#  -1.75907089e+01 -5.76261188e-01 -7.54298371e+00 -4.99323281e+00
#  -1.10119837e+01  2.88815458e+00  3.27413059e+00  2.26045032e+00
#  -2.42511688e+00  5.84854084e-01 -5.87692619e+00  5.51565672e+00
#  -2.68264081e+00 -1.37743078e+00  2.96127237e+00 -7.93929026e+00
#   3.41361301e+00  1.01723045e+01  2.07040132e+00  7.72164729e+00
#  -9.90310395e+00 -2.15586497e+00  1.11171963e+00 -1.23105524e+01
#   3.18429290e+00  1.18880034e+01 -2.42548740e+01 -1.05721621e+01
#   1.55742357e+00  4.63190466e+00  8.83285070e+00  1.03237191e+00
#   3.32016288e-01  1.62395225e+00 -3.96716005e+00 -5.16024324e+00
#  -2.70562820e+00  1.96510829e-01 -5.72396781e+00 -5.23907722e+00
#  -1.72850417e-01  9.50068120e-01 -1.42597100e+00 -5.96527857e+00
#  -8.20801501e-01 -7.64766789e+00  3.01663214e+00 -3.13494508e+00
#  -9.99829082e+00 -1.76755729e+00  1.39239919e+00  5.73155034e+00
#  -6.06066888e-01 -7.95462275e+00  3.48242503e+00 -8.27836406e+00
#   5.97189140e+00 -5.46043639e+00  6.76154600e+00  8.78429903e+00
#   3.45757257e+00  7.28627110e+00 -3.02130969e+00 -5.80134028e+00
#  -1.39756168e+00 -3.70490675e+00  1.02766827e+01 -1.00515848e+01
#   4.84915798e+00  2.43731948e+00  9.49496412e-01  9.51990785e+00
#  -1.77205098e+00 -8.76661253e+00  1.03541770e+00 -3.24488249e+00
#   4.61744356e-01  7.15420194e+00 -4.36445085e+00  5.67865804e+00
#  -3.49459131e+00  2.99716486e+00 -9.57327126e-01  1.19563003e+00
#  -3.09966583e+00 -8.29034911e+00 -5.10053035e+00  6.41123952e+00
#  -3.87524258e+00 -1.16681932e+01 -3.82657829e+00 -2.13751364e+00
#  -1.53079462e+01 -9.89870924e+00 -6.28101542e+00 -1.73317191e+01
#  -9.21210577e+00 -8.31425448e+00 -1.50559911e+01  1.17604821e+00
#   1.01627772e+01  8.29352611e+00  2.42567803e+00  3.85695406e+00
#   9.11635360e+00 -1.76697963e+00  4.07833501e+00  1.04174921e+01
#  -2.80169838e+00  1.18368434e+01 -9.67517001e+00 -6.44239546e+00
#  -1.52432772e+00 -9.56025000e-01 -1.10814620e+01  1.82839430e+00
#  -2.25675892e+00 -8.21727858e+00 -1.94891242e+00 -2.55494700e+00
#  -6.90452023e-01 -1.38557785e+01  1.15718260e+01  4.16844676e+00
#   1.07248542e+01 -1.46022444e+00 -1.69861513e+00 -5.74660453e+00
#   5.29783821e+00 -1.10355662e+00 -2.93979909e+00  6.72442208e+00
#   1.08255284e+01 -8.69595422e-01  5.82871580e-01 -4.59060894e+00
#   1.47840827e+01 -1.20402647e+01 -1.02975376e+01 -4.33887075e-01
#   3.60045501e+00  5.96810839e+00 -5.78229361e-01  4.22154762e+00
#  -5.32654829e+00 -8.72887329e+00 -8.31685131e+00  1.15133734e+01
#   7.62294006e+00  9.74788891e-01  4.17556328e+00  1.98096613e+01
#  -3.41523099e-01 -5.17401404e+00  1.03059055e+01  2.18990473e+00]
#
# Results for polynomial with degree 6:
# Estimated polynomial coefficients: [-1.63864293e+01  2.28207004e+01 -5.13527465e-01 -3.58096979e+00
#   1.39914556e-01  1.36073672e-01 -9.05453557e-03]
# Uncertainty in estimated coefficients: [[ 6.11169063e-01  1.61738219e-14 -5.55130058e-01 -7.05634747e-15
#    1.23255407e-01  6.17340948e-16 -7.70045298e-03]
#  [ 3.22572811e-14  7.40152683e-01 -6.22609191e-14 -2.68908336e-01
#    1.79233801e-14  2.13229381e-02 -1.28408244e-15]
#  [-5.55130058e-01 -2.81743980e-14  9.07607994e-01  1.21800085e-14
#   -2.39898728e-01 -1.06060155e-15  1.63199750e-02]
#  [-1.36255417e-14 -2.68908336e-01  2.62029096e-14  1.16306935e-01
#   -7.53016086e-15 -1.00422179e-02  5.38860852e-16]
#  [ 1.23255407e-01  7.70370336e-15 -2.39898728e-01 -3.31496089e-15
#    6.90460483e-02  2.87930792e-16 -4.94108528e-03]
#  [ 1.16649478e-15  2.13229381e-02 -2.23864592e-15 -1.00422179e-02
#    6.42689067e-16  9.12106703e-04 -4.59582440e-17]
#  [-7.70045298e-03 -5.34499788e-16  1.63199750e-02  2.29288191e-16
#   -4.94108528e-03 -1.98798521e-17  3.65681563e-04]]
# Posterior variance factor: 63.85863154212097
# Observation residuals: [ 2.63786328e+00  3.08053944e+00 -1.94857354e+01  3.62882588e+00
#   2.38631320e-01  4.62827097e+00  4.50041069e+00  3.28658249e+00
#   2.89066618e+00 -1.23264340e+01  4.84348173e+00 -3.98072235e+00
#   6.39344133e+00  5.71146694e+00 -5.02020341e+00  9.31228981e+00
#  -1.30954316e+00 -6.88395903e+00  2.84680647e+00 -1.26308015e+01
#   1.88219884e-01 -4.38053504e+00 -6.72316293e-01  2.89699721e+00
#  -1.51528769e+00 -1.10916382e+00 -6.33246073e+00  2.03976637e+01
#   2.55516739e+00  2.77470395e+00  6.26337173e+00 -2.87764871e+00
#   6.94911763e+00  3.52042559e+00 -1.55651825e+01 -1.13940130e+01
#  -5.54187126e-01 -1.58447811e+01 -1.19365506e+00 -3.05183846e+00
#  -1.15565837e-01  5.62286676e+00 -4.24075393e-01 -9.42054954e-01
#   3.84610219e+00 -1.43143590e+00  9.23753294e+00  4.41626222e+00
#   3.48125195e-01  7.31883253e-01  2.85462499e+01  6.56012312e+00
#   2.41614488e+01  5.82225526e+00 -2.96968117e+00 -2.38160824e+00
#  -2.21200156e+01  4.74247257e+00  2.97483095e+00 -3.54464192e+00
#  -3.92868074e+00  1.49903910e+00 -1.19628702e+01 -1.27065679e+01
#   7.46387301e+00  1.41582394e+00 -5.11457931e-01 -2.36355439e+01
#   1.19945989e+01 -6.09135758e+00  3.79834643e+00  4.38122255e+00
#  -7.18090745e+00 -2.76183757e+00  1.90480557e+01 -1.37496221e-01
#  -3.47037939e+00  2.96557567e-01 -4.00575047e+00  8.67899191e-01
#  -2.27296225e-01  8.91382096e+00 -1.38879811e+00 -1.13305321e+01
#  -1.21746235e+00 -1.23566145e+00 -5.84675023e-01  5.27275562e+00
#   3.68142900e+00  3.80625591e+00 -7.90255776e+00  2.16074545e+00
#   4.58560918e+00 -3.14513392e+00 -1.01581360e+00 -1.37661248e+01
#   6.58514335e+00 -8.37199191e-01  8.30879278e+00  1.48201044e+00
#  -2.34433772e+00 -6.12127659e+00 -1.67278430e+01 -2.30853811e+01
#  -7.06000357e+00  9.36769344e+00 -1.03283291e+00 -1.81648044e+01
#   6.99369394e+00  9.70936434e+00  4.12663734e+00  4.29477784e+00
#  -6.78569609e-01 -1.41047359e+01 -7.00629741e+00 -2.92263380e+00
#  -3.31695105e+00 -2.21416301e-01  3.55331900e+00 -4.42223020e+00
#   1.21246717e+01 -4.37780022e+00  2.29659655e+00  1.42458694e+00
#  -6.61167946e-01  4.13159314e-01 -3.32266716e+00  1.55167395e+00
#   2.46239331e+00  9.46234585e-02 -4.99860238e+00 -3.20190080e+00
#   3.63677165e+00  2.94071239e+00 -1.52181101e+01  1.01654780e+01
#  -1.66428363e+01  1.04159514e+01  4.24271314e+00  2.20547338e+00
#  -1.40940282e+00  1.81717534e+00  1.40737630e+01  2.44126543e+00
#  -9.32086533e+00  1.92511450e+00  1.17579164e+00  1.54278023e+01
#  -1.80865129e-01  1.73022828e+00  4.54238687e+00 -8.18041894e-01
#   1.95870256e+01 -1.28083414e+01  8.86234315e+00  3.31157165e+00
#   4.42716730e-01  3.04939568e+01 -1.88620818e+00 -4.21485149e+00
#   1.23139712e+00  6.50965253e-01  7.57097114e+00  3.35051105e-01
#   1.12452665e+00  2.07562239e+01 -5.18061615e+00 -1.61598742e+00
#   9.39253626e+00 -2.35176557e+00 -4.19907538e+00  5.34758136e+00
#   1.31285913e+01 -9.44278124e-01 -1.76800260e+00 -2.85198052e+00
#  -4.11939656e+00  1.05539631e+01 -1.30297215e-01 -2.71763971e+00
#   3.09788448e+00  1.12402404e+01 -8.94749788e-01 -1.89432056e+01
#   3.03190586e+01 -8.63331871e+00 -5.03896782e+00  1.01168658e+00
#  -6.62795667e-01 -1.22353966e+00  7.09035890e+00 -7.59257938e+00
#  -6.76061993e+00 -3.01954587e-01 -4.48533611e+00 -6.32097618e-02
#   2.72758425e+00 -2.16267169e+01  3.34561503e+00 -2.97426481e+00
#  -1.17420435e+01  5.44133322e-01 -7.60947267e-02  6.85043987e-01
#   8.40991673e-01  1.10561934e+01 -5.22215429e+00  3.00153564e-02
#  -7.23188365e+00  4.27587421e-01 -1.01190008e+00 -2.76229109e+00
#  -1.60499914e+00  4.58444202e+00 -3.78977923e+00 -3.27899569e+00
#  -6.24571683e-01 -1.00174671e+01 -1.77091916e-01 -7.99278951e-01
#  -9.02195176e+00 -1.36812340e+01 -1.63486054e+01 -1.76981775e+01
#  -4.39631115e-01  1.26023743e+00  1.80647889e+00 -7.61967813e+00
#  -6.93509947e-01  2.55597876e+00 -1.20357759e+01 -1.31414233e-01
#   2.65660320e+00 -7.49748398e+00  7.87052891e+00 -6.23703114e+00
#  -9.22870407e+00  7.16759960e+00  1.15716977e+01  3.96481964e-01
#   3.81708616e+00 -2.15273970e+00 -9.31703588e+00  1.37051408e+00
#   3.91815522e+00 -3.48532572e+00  5.69011113e+00 -4.54317829e+00
#  -9.63763495e+00  8.93110728e+00  1.32370976e+01 -4.41606135e+00
#   2.00187802e+01 -3.18865384e+00  5.00367438e-01 -9.37387756e-01
#   3.59448135e+00  2.39335474e+00  4.43023593e-01 -2.62435737e+00
#  -1.74671357e+01  1.19860962e+01 -5.48270666e+00 -8.14768917e-01
#   7.41799440e-01  2.69694010e+00 -3.95296886e-01 -4.89490059e+00
#  -4.21231168e+00 -7.66920866e-01 -2.35669759e+00 -3.02064177e-01
#  -1.10030643e+00  6.04307573e+00 -1.18671007e+00 -1.39841181e+01
#   1.28601184e+01  9.06622548e+00  2.03267558e+01 -1.43791403e+01
#  -2.26043688e+00  8.96131461e+00  4.35277694e+00  1.06553345e+00
#  -2.24596436e+01 -9.02009111e+00  2.58280820e+00  8.03009215e+00
#  -7.60822773e-01  9.29781559e+00 -1.06617612e+01 -4.39592424e+00
#  -9.23635506e+00 -1.26236319e+00  1.76129607e+00 -2.98821906e+00
#   1.97621293e+01  1.91036822e+00  1.26298780e+01  4.03051740e+00
#   1.54120125e+01 -8.18008626e+00  1.08420142e+00 -7.55570409e-02
#   5.69413196e+00 -6.10528391e+00  1.46390576e+00  9.70249901e-01
#  -4.66660380e+00  1.55163264e+00  1.04549500e+01 -1.01375769e+00
#   6.48847953e-01 -9.32788947e+00  2.71186747e+01  9.89999404e+00
#   3.15461065e+00  7.77317585e+00  3.61853900e+00  8.43850761e+00
#  -1.50806689e+00 -1.16012885e+01  2.41140380e+00 -1.02516979e+00
#  -1.36813876e+00  1.00915973e+00 -1.93516963e+00  1.41301053e+01
#  -4.98878692e+00 -1.19433739e+00  8.99925492e-01  2.55020830e+00
#  -7.63286561e+00  1.04441006e+00  2.71974944e+00 -3.11269238e+00
#   5.14262243e+00 -1.93751113e+00 -1.60558400e+00  1.94273028e+00
#   4.21387064e-01  1.65246536e+01  2.74153413e+00  1.30769441e+01
#  -1.90145505e+01 -1.97341945e+00 -8.91261360e+00 -6.33449838e+00
#  -1.23240586e+01  1.60608672e+00  2.02287559e+00  1.04080309e+00
#  -3.61237285e+00 -5.69239007e-01 -6.99709713e+00  4.43015440e+00
#  -3.73274133e+00 -2.39141008e+00  1.98411948e+00 -8.87892625e+00
#   2.51216919e+00  9.30971241e+00  1.24730448e+00  6.93867246e+00
#  -1.06453471e+01 -2.85678453e+00  4.52697583e-01 -1.29271218e+01
#   2.61071245e+00  1.13579283e+01 -2.47409475e+01 -1.10137582e+01
#   1.16075939e+00  4.28060529e+00  8.52732686e+00  7.73011622e-01
#   1.19184393e-01  1.45798985e+00 -4.08593607e+00 -5.23154077e+00
#  -2.72918042e+00  2.20944955e-01 -5.65133266e+00 -5.11805323e+00
#  -3.27716371e-03  1.16832313e+00 -1.15893019e+00 -5.64937693e+00
#  -4.55993527e-01 -7.23393815e+00  3.47926846e+00 -2.62344853e+00
#  -9.43801207e+00 -1.15860662e+00  2.04987869e+00  6.43738227e+00
#   1.47907167e-01 -7.15275131e+00  4.33191412e+00 -7.38157259e+00
#   6.91563387e+00 -4.47013095e+00  7.79798917e+00  9.86641690e+00
#   4.58486381e+00  8.45819546e+00 -1.80533189e+00 -4.54192876e+00
#  -9.53767348e-02 -2.36064982e+00  1.16622684e+01 -8.62545564e+00
#   6.31500223e+00  3.94200711e+00  2.49211174e+00  1.10994906e+01
#  -1.56506209e-01 -7.11615685e+00  2.71968690e+00 -1.52794401e+00
#   2.21016043e+00  8.93285592e+00 -2.55684726e+00  7.51387380e+00
#  -1.63315056e+00  4.88339307e+00  9.52200136e-01  3.12691643e+00
#  -1.14821225e+00 -6.32037297e+00 -3.11372950e+00  8.41311343e+00
#  -1.86010169e+00 -9.64164640e+00 -1.79054208e+00 -9.39608398e-02
#  -1.32589063e+01 -7.84626903e+00 -4.22731962e+00 -1.52789710e+01
#  -7.16256750e+00 -6.27024806e+00 -1.30198987e+01  3.20178345e+00
#   1.21756508e+01  1.02909717e+01  4.40506650e+00  5.81559310e+00
#   1.10514872e+01  1.41828029e-01  5.95793140e+00  1.22649263e+01
#  -9.89443404e-01  1.36108354e+01 -7.94259207e+00 -4.75445053e+00
#   1.15696772e-01  6.32722551e-01 -9.54741759e+00  3.30423927e+00
#  -8.42680669e-01 -6.86860568e+00 -6.69355499e-01 -1.34828929e+00
#   4.39450100e-01 -1.28065621e+01  1.25363522e+01  5.04420326e+00
#   1.15076862e+01 -7.74548092e-01 -1.11440206e+00 -5.26823968e+00
#   5.66589205e+00 -8.50354985e-01 -2.80606988e+00  6.73397908e+00
#   1.07061333e+01 -1.12280343e+00  1.90908720e-01 -5.12635056e+00
#   1.40994560e+01 -1.28789660e+01 -1.12955865e+01 -1.59664074e+00
#   2.26755453e+00  4.45953375e+00 -2.26809141e+00  2.34469841e+00
#  -7.39617143e+00 -1.09971448e+01 -1.07897338e+01  8.82982861e+00
#   4.72259232e+00 -2.14859239e+00  8.22827457e-01  1.62211589e+01
#  -4.17229564e+00 -9.25365244e+00  5.97071281e+00 -2.40762387e+00]

# %%
# step 7
# use the estimated coefficients x and constants array a, construct polynomial functions for each degree
# hint: use polyval function from numpy library (check input argument carefully)
# (1 marks)

quadratic_uw = np.polyval(results[2]['x'][::-1], a)
quartic_uw = np.polyval(results[4]['x'][::-1], a)
hexic_uw = np.polyval(results[6]['x'][::-1], a)

# %%
# step 8
# use the matplotlib to plot each polynomial function, noisy observations l, true observations l_true, together in one single figure
# for the polynomials of line, cubic and quintic, use color of orange, green and red respectively.
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot (a, l_true, label='f(a)', color= 'k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o',alpha =0.3)
ax.plot (a, quadratic_uw, label='Quadratic function', color='orange')
ax.plot (a, quartic_uw, label='Quartic function', color='green' )
ax.plot (a, hexic_uw, label ='Hexic function', color='red')
ax.set_xlabel ("a")
ax.set_ylabel ("Observations")
ax.set_title ("Plot of True and Noisy Observations with Quadratic, Quartic and Hexic Functions")
ax.legend (loc='best')
ax.set_xlim (-1,1)


ax.grid(True, which='both',ls='-',color='0.65')

fig.tight_layout()

# %%
# step 9
# print the a posterier variance factor for each polynomial function
# (3 marks)
print("Posterior Variance Factor for Each Polynomial:")
for deg in degree:
    print(f"Posterior variance factor for degree {deg} = {results[deg]['apv']}")
# Out:
# Posterior Variance Factor for Each Polynomial:
# Posterior variance factor for degree 2 = 163.0561531810196
# Posterior variance factor for degree 4 = 66.24842817291719
# Posterior variance factor for degree 6 = 63.85863154212097

# %%
# step 10
# compute and print the norm between the predicted observations (output from each polynomial function) and the true observations
# (3 marks)

#computing and printing norm for quadratic function
norm_quadratic = np.linalg.norm(l_true - quadratic_uw)
print(f"Norm for Quadratic function: {norm_quadratic}")

#computing and pritning norm for quartic funciton
norm_quartic = np.linalg.norm(l_true - quartic_uw)
print(f"Norm for Quartic function: {norm_quartic}")

#computing and printing norm for hexic function
norm_hexic = np.linalg.norm(l_true - hexic_uw)
print(f"Norm for Hexic function: {norm_hexic}")
# Out:
# Norm for Quadratic function: 229.07525292632084
# Norm for Quartic function: 38.39862130171954
# Norm for Hexic function: 17.77730737398275

# %%
# step 11
# comment on the results of a posterier variance factor and norm, what pattern do you observe
# (2 marks)

# From the calculated posterior variance factor and norm value, it can be observed that as the degree of the polynomial increases, the norm and posterior variance factor decreaase.
# The norm represents the residuals in curve fitting. A smaller norm means that residuals are smallers, indicating that the true oberservations are close to the predicted values.
# The quadratic function has the largest norm and while the hexic function has the smallest norm.
# The posterior variance factor is a measure of the goodness of fit in curve fittting. The smaller the values, the smaller the variance of the measurements.
# The quadratic function has the largest posterior variance factor while the hexic function has the smallest.

# When both norm and posterior variance factor are taken into account, we can determine which model best fits our data.
# In this case, as the degree of the polynomial increases, the fit of the curve improves, meaning that the model is able to accurately describe the pattern in our dataset, residuals are small and estimated coefficients are reliable.
# Continuing to increase the degree will eventually lead to a point where improvements are small. When this occurs, there is a risk of overfitting, which is when the model becomes too complex for the dataset, leading to high variance and poor generalization

# %%
# step 12
# now, let's define the P matrix with the proper weights of observation
# use the variance of observation l_var, define P matrix
# (1 mark)
P = np.diag(1.0/l_var)

# %%
# step 13
# repeat the steps 6-10, using the proper P matrix
# (7 marks)

#Step 6: Calling the fit_polynomial_curve function with weight matrix P and getting the results
degree = [2,4,6]
results = {}

for deg in degree:
    x, cov_x, apv, v = fit_polynomial_curve(a, l, P, deg)
    results[deg]= {'x':x,
                   'cov_x' : cov_x,
                   'apv': apv,
                   'v':v }

    print(f"Results for polynomial with degree {deg}:")
    print(f"Estimated polynomial coefficients: {results[deg]['x']}")
    print(f"Uncertainty in estimated coefficients: {results[deg]['cov_x']}")
    print(f"Posterior variance factor: {results[deg]['apv']}")
    print(f"Observation residuals: {results[deg]['v']}\n")


#Step 7:Using the estimated coefficients x and constants array a to construct polynomial functions for each degree with weight matrix P
quadratic_uw = np.polyval(results[2]['x'][::-1], a)
quartic_uw = np.polyval(results[4]['x'][::-1], a)
hexic_uw = np.polyval(results[6]['x'][::-1], a)


#Step 8:Using matplotlib to plot each polynomial function, noisy observations l, true observations l_true, in one single figure
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot (a, l_true, label='f(a)', color= 'k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o',alpha =0.3)
ax.plot (a, quadratic_uw, label='Weighted Quadratic function', color='orange')
ax.plot (a, quartic_uw, label='Weighted Quartic function', color='green' )
ax.plot (a, hexic_uw, label ='Weighted Hexic function', color='red')
ax.set_xlabel ("a")
ax.set_ylabel ("Observations")
ax.set_title ("Plot of True and Noisy Observations with Weighted Quadratic, Quartic and Hexic Functions")
ax.legend (loc='best')
ax.set_xlim (-1,1)


ax.grid(True, which='both',ls='-',color='0.65')

fig.tight_layout()


#Step 9: Printing the a posterier variance factor for each polynomial function created with weight matrix P
print("Posterior Variance Factor for Each Polynomial:")
for deg in degree:
    print(f"Posterior variance factor for degree {deg} = {results[deg]['apv']}")
print()


#computing and printing norm for functions
print ("Norms of Weighted Equations:")
v2 = results [2]['v']
v4 = results [4]['v']
v6 = results [6]['v']


norm_quadratic = np.linalg.norm(l_true - quadratic_uw)
print(f"Norm for Quadratic function: {norm_quadratic}")

norm_quartic = np.linalg.norm(l_true - quartic_uw)
print(f"Norm for Quartic function: {norm_quartic}")

norm_hexic = np.linalg.norm(l_true - hexic_uw)
print(f"Norm for Hexic function: {norm_hexic}")
# Out:
# Results for polynomial with degree 2:
# Estimated polynomial coefficients: [-16.8015757    7.68372831   0.08553357]
# Uncertainty in estimated coefficients: [[ 0.50943988 -0.0045098  -0.08996208]
#  [-0.0045098   0.07993342  0.00181672]
#  [-0.08996208  0.00181672  0.02998579]]
# Posterior variance factor: 12.072979326943319
# Observation residuals: [ 2.39016486e+01  2.40703972e+01  1.22592322e+00  2.40581749e+01
#   2.03817194e+01  2.44813041e+01  2.40597501e+01  2.25487425e+01
#   2.18523125e+01  6.33151382e+00  2.31946937e+01  1.40608619e+01
#   2.41226497e+01  2.31256931e+01  1.20765740e+01  2.60892900e+01
#   1.51454876e+01  9.24704428e+00  1.86518569e+01  2.84650143e+00
#   1.53361094e+01  1.04364022e+01  1.38122553e+01  1.70479132e+01
#   1.23008045e+01  1.23710564e+01  6.81095757e+00  3.32034667e+01
#   1.50226566e+01  1.49032938e+01  1.80525882e+01  8.57183008e+00
#   1.80586024e+01  1.42897665e+01 -5.13603068e+00 -1.30499227e+00
#   9.19486178e+00 -6.43544486e+00  7.87632600e+00  5.67924140e+00
#   8.27716187e+00  1.36778848e+01  7.29396734e+00  6.43983717e+00
#   1.08927572e+01  5.28098263e+00  1.56168014e+01  1.04635513e+01
#   6.06468813e+00  6.11905455e+00  3.36054437e+01  1.12928320e+01
#   2.85692419e+01  9.90677705e+00  7.93287749e-01  1.06159866e+00
#  -1.89947089e+01  7.55181062e+00  5.47020001e+00 -1.36117537e+00
#  -2.05498477e+00  3.06516048e+00 -1.07020648e+01 -1.17487583e+01
#   8.12106677e+00  1.77484059e+00 -4.48122333e-01 -2.38653372e+01
#   1.14742835e+01 -6.89953478e+00  2.70501992e+00  3.00551009e+00
#  -8.83619285e+00 -4.69383453e+00  1.68422557e+01 -2.61414483e+00
#  -6.21487749e+00 -2.71274745e+00 -7.27677754e+00 -2.66172401e+00
#  -4.01234974e+00  4.87654167e+00 -5.67506109e+00 -1.58625002e+01
#  -5.99182202e+00 -6.24906475e+00 -5.83374112e+00 -2.08560575e-01
#  -2.02869382e+00 -2.12920043e+00 -1.40598459e+01 -4.21484531e+00
#  -2.00472857e+00 -9.94663768e+00 -8.02487809e+00 -2.09791214e+01
#  -8.28134658e-01 -8.44708656e+00  5.05988256e-01 -6.50999985e+00
#  -1.05218242e+01 -1.44804925e+01 -2.52650253e+01 -3.17967515e+01
#  -1.59417694e+01  3.19337946e-01 -1.02439597e+01 -2.75348727e+01
#  -2.53147556e+00  3.29436122e-02 -5.69717594e+00 -5.67256148e+00
#  -1.07855616e+01 -2.43475010e+01 -1.73809509e+01 -1.34252868e+01
#  -1.39437111e+01 -1.09683883e+01 -7.30996809e+00 -1.53979346e+01
#   1.04044794e+00 -1.55666461e+01 -8.99297572e+00 -9.96181819e+00
#  -1.21405155e+01 -1.11552441e+01 -1.49762444e+01 -1.01832005e+01
#  -9.34990791e+00 -1.17912409e+01 -1.69541738e+01 -1.52233316e+01
#  -8.44667982e+00 -9.20093088e+00 -2.74141267e+01 -2.08110464e+00
#  -2.89361896e+01 -1.92038956e+00 -8.13284570e+00 -1.02055475e+01
#  -1.38521442e+01 -1.06535604e+01  1.57874342e+00 -1.00743439e+01
#  -2.18533874e+01 -1.06206609e+01 -1.13795959e+01  2.86642488e+00
#  -1.27446296e+01 -1.08323404e+01 -8.01542381e+00 -1.33675535e+01
#   7.04933245e+00 -2.53307190e+01 -3.64124465e+00 -9.16977542e+00
#  -1.20129626e+01  1.80673479e+01 -1.42803689e+01 -1.65732117e+01
#  -1.10878362e+01 -1.16258411e+01 -4.66013520e+00 -1.18471094e+01
#  -1.10054701e+01  8.68158067e+00 -1.71967451e+01 -1.35704702e+01
#  -2.49719828e+00 -1.41736798e+01 -1.59501277e+01 -6.32959829e+00
#   1.52826371e+00 -1.24648060e+01 -1.32058150e+01 -1.42041944e+01
#  -1.53831617e+01 -6.18536132e-01 -1.12087471e+01 -1.36992908e+01
#  -7.78425265e+00  4.60297796e-01 -1.15698523e+01 -2.95108578e+01
#   1.98614312e+01 -1.89783827e+01 -1.52689660e+01 -9.10078004e+00
#  -1.06553018e+01 -1.10936936e+01 -2.65508860e+00 -1.72110038e+01
#  -1.62497427e+01 -9.65953543e+00 -1.37091732e+01 -9.15113995e+00
#  -6.22231499e+00 -3.04365004e+01 -5.32200727e+00 -1.14977202e+01
#  -2.01193663e+01 -7.68513113e+00 -8.15541548e+00 -7.24248821e+00
#  -6.93294782e+00  3.43760986e+00 -1.26836596e+01 -7.27273083e+00
#  -1.43742311e+01 -6.55276331e+00 -7.82869778e+00 -9.41402132e+00
#  -8.09018944e+00 -1.73277805e+00 -9.93764101e+00 -9.25615350e+00
#  -6.42972234e+00 -1.56493500e+01 -5.63448925e+00 -6.08101563e+00
#  -1.41268956e+01 -1.86082958e+01 -2.10967391e+01 -2.22663801e+01
#  -4.82694284e+00 -2.94526688e+00 -2.21634480e+00 -1.14589914e+01
#  -4.34852634e+00 -9.13997814e-01 -1.53200132e+01 -3.22925624e+00
#  -2.54231123e-01 -1.02207417e+01  5.33537305e+00 -8.58360334e+00
#  -1.13862544e+01  5.19946573e+00  9.79333140e+00 -1.19180918e+00
#   2.41913423e+00 -3.36013182e+00 -1.03336910e+01  5.44729636e-01
#   3.28333188e+00 -3.92914086e+00  5.43730803e+00 -4.60500869e+00
#  -9.50857513e+00  9.25093181e+00  1.37475183e+01 -3.71525579e+00
#   2.09097164e+01 -2.10788393e+00  1.77063155e+00  5.21988515e-01
#   5.24254534e+00  4.22963971e+00  2.46702063e+00 -4.13199243e-01
#  -1.50694094e+01  1.45697560e+01 -2.71378966e+00  2.13868738e+00
#   3.87903580e+00  6.01715608e+00  3.10705721e+00 -1.21129079e+00
#  -3.48369308e-01  3.27639037e+00  1.86497844e+00  4.09693234e+00
#   3.47492627e+00  1.07934205e+01  3.73758293e+00 -8.88708002e+00
#   1.81286591e+01  1.45049872e+01  2.59344183e+01 -8.60393581e+00
#   3.68091225e+00  1.50673730e+01  1.06220712e+01  7.49655254e+00
#  -1.58684481e+01 -2.27030497e+00  9.48956238e+00  1.50921550e+01
#   6.45485298e+00  1.66653722e+01 -3.14409162e+00  3.27005476e+00
#  -1.42390564e+00  6.69468258e+00  9.86102928e+00  5.25225813e+00
#   2.81413728e+01  1.04263663e+01  2.12805853e+01  1.28138553e+01
#   2.43258692e+01  8.62144756e-01  1.02526298e+01  9.21685955e+00
#   1.51082959e+01  3.42835501e+00  1.11147161e+01  1.07358974e+01
#   5.21151598e+00  1.15398297e+01  2.05507996e+01  9.18729015e+00
#   1.09526107e+01  1.07607604e+00  3.76203025e+01  2.04967155e+01
#   1.38438296e+01  1.85522687e+01  1.44848553e+01  1.93893702e+01
#   9.52463886e+00 -4.89468630e-01  1.35995832e+01  1.02365897e+01
#   9.96439671e+00  1.24096428e+01  9.53040868e+00  2.56579032e+01
#   6.59833179e+00  1.04491808e+01  1.25968994e+01  1.42976726e+01
#   4.16210217e+00  1.28838735e+01  1.46006801e+01  8.80665706e+00
#   1.70973224e+01  1.00494518e+01  1.04105356e+01  1.39848817e+01
#   1.24864276e+01  2.86094231e+01  1.48428552e+01  2.51916228e+01
#  -6.88972424e+00  1.01583285e+01  3.22281490e+00  5.80135479e+00
#  -1.91051006e-01  1.37329646e+01  1.41403262e+01  1.31455159e+01
#   8.47627928e+00  1.15000175e+01  5.04941723e+00  1.64505691e+01
#   8.25820576e+00  9.56669124e+00  1.39059873e+01  3.00331135e+00
#   1.43513712e+01  2.11024653e+01  1.29901871e+01  1.86282567e+01
#   9.87503835e-01  8.71589232e+00  1.19617538e+01 -1.48513776e+00
#   1.39821680e+01  2.26553953e+01 -1.35209329e+01  1.25337114e-01
#   1.22154661e+01  1.52474521e+01  1.94028410e+01  1.15537193e+01
#   1.08016114e+01  1.20386621e+01  6.38950805e+00  5.13520294e+00
#   7.52539232e+00  1.03598784e+01  4.36849594e+00  4.77920830e+00
#   9.76795893e+00  1.08100798e+01  8.34989804e+00  3.72307932e+00
#   8.77665324e+00  1.85546823e+00  1.24220107e+01  6.16921345e+00
#  -7.98838176e-01  7.32368017e+00  1.03718887e+01  1.45957357e+01
#   8.13923479e+00  6.68192244e-01  1.19791270e+01  8.85750689e-02
#   1.42053946e+01  2.63593439e+00  1.47170645e+01  1.65952222e+01
#   1.11201338e+01  1.47966806e+01  4.33313501e+00  1.39330320e+00
#   5.63342088e+00  3.15853193e+00  1.69686712e+01 -3.53497580e+00
#   1.11864347e+01  8.59128790e+00  6.91615740e+00  1.52952390e+01
#   3.80790480e+00 -3.38610092e+00  6.21239320e+00  1.72444178e+00
#   5.21927913e+00  1.16957858e+01 -4.30024771e-02  9.77576326e+00
#   3.73939963e-01  6.63286828e+00  2.44127146e+00  4.35282370e+00
#  -1.88200209e-01 -5.62895776e+00 -2.69358252e+00  8.55935154e+00
#  -1.99038171e+00 -1.00510219e+01 -2.48155776e+00 -1.06912831e+00
#  -1.45207034e+01 -9.39713931e+00 -6.06967163e+00 -1.74151777e+01
#  -9.59496592e+00 -9.00113831e+00 -1.60515436e+01 -1.32841012e-01
#   8.53586042e+00  6.34386808e+00  1.48542099e-01  1.24758072e+00
#   6.16996048e+00 -5.05519772e+00  4.43463895e-01  6.43111705e+00
#  -7.14445099e+00  7.13281672e+00 -1.47453901e+01 -1.18837511e+01
#  -7.34178365e+00 -7.15456889e+00 -1.76661043e+01 -5.14737939e+00
#  -9.62871993e+00 -1.59905055e+01 -1.01285065e+01 -1.11460322e+01
#  -9.69817511e+00 -2.32853088e+01  1.71529650e+00 -6.12029669e+00
#  -1.34044837e-03 -1.26291304e+01 -1.33155149e+01 -1.78168033e+01
#  -7.23098745e+00 -1.40963596e+01 -1.64019523e+01 -7.21247699e+00
#  -3.59153464e+00 -1.57722632e+01 -1.48108641e+01 -2.04808983e+01
#  -1.60826858e+00 -2.89402088e+01 -2.77106277e+01 -1.83656990e+01
#  -1.48556770e+01 -1.30179645e+01 -2.00998862e+01 -1.58413589e+01
#  -2.59363925e+01 -2.98913658e+01 -3.00377249e+01 -1.07716367e+01
#  -1.52319841e+01 -2.24558495e+01 -1.98366118e+01 -4.78989535e+00
#  -2.55343284e+01 -3.09659576e+01 -1.60910881e+01 -2.48180731e+01]
#
# Results for polynomial with degree 4:
# Estimated polynomial coefficients: [-16.57861487  20.32277776  -0.23984115  -2.23145473   0.02456981]
# Uncertainty in estimated coefficients: [[ 8.37510425e-02 -1.92914396e-03 -4.50959364e-02  3.65081225e-04
#    4.37144000e-03]
#  [-1.92914396e-03  4.13360446e-02  1.46605686e-03 -5.96641246e-03
#   -1.92827115e-04]
#  [-4.50959364e-02  1.46605686e-03  4.05477211e-02 -3.31470020e-04
#   -4.50693170e-03]
#  [ 3.65081225e-04 -5.96641246e-03 -3.31470020e-04  1.05470882e-03
#    4.63620541e-05]
#  [ 4.37144000e-03 -1.92827115e-04 -4.50693170e-03  4.63620541e-05
#    5.38750359e-04]]
# Posterior variance factor: 1.1441867042253173
# Observation residuals: [-4.98567337e+00 -4.13501752e+00 -2.63045808e+01 -2.80438463e+00
#  -5.81983131e+00 -1.06614326e+00 -8.40469025e-01 -1.71109298e+00
#  -1.77395366e+00 -1.66679672e+01  8.15244177e-01 -7.70527962e+00
#   2.96312299e+00  2.56611822e+00 -7.88968170e+00  6.70975102e+00
#  -3.65390698e+00 -8.97874785e+00  9.93155335e-01 -1.42515914e+01
#  -1.20782617e+00 -5.55979744e+00 -1.64259981e+00  2.12804146e+00
#  -2.09041497e+00 -1.49781182e+00 -6.54183032e+00  2.03605182e+01
#   2.68333664e+00  3.06142158e+00  6.70201286e+00 -2.29356926e+00
#   7.67228823e+00  4.37647653e+00 -1.45823274e+01 -1.02902968e+01
#   6.64578305e-01 -1.45166485e+01  2.38290884e-01 -1.52150668e+00
#   1.50784922e+00  7.33418580e+00  1.37009006e+00  9.30019470e-01
#   5.79126671e+00  5.82116875e-01  1.13148876e+01  6.55294631e+00
#   2.53977874e+00  2.97425716e+00  3.08352045e+01  8.89162670e+00
#   2.65315761e+01  8.22718589e+00 -5.33663938e-01  8.18808920e-02
#  -1.96325687e+01  7.25046252e+00  5.50004684e+00 -1.00542077e+00
#  -1.37857999e+00  4.05698738e+00 -9.40001427e+00 -1.01416532e+01
#   1.00280869e+01  3.97666581e+00  2.04342740e+00 -2.10891141e+01
#   1.45301584e+01 -3.56900035e+00  6.30525106e+00  6.87050453e+00
#  -4.71133917e+00 -3.13996260e-01  2.14722333e+01  2.26115599e+00
#  -1.09904004e+00  2.63886927e+00 -1.69410960e+00  3.14729637e+00
#   2.01835357e+00  1.11242876e+01  7.85116494e-01 -9.19447285e+00
#   8.79502576e-01  8.21033619e-01  1.43063678e+00  7.24563177e+00
#   5.61087702e+00  5.69134210e+00 -6.06270939e+00  3.95453660e+00
#   6.33257922e+00 -1.44569445e+00  6.35439200e-01 -1.21636624e+01
#   8.13826274e+00  6.66074923e-01  9.76176852e+00  2.88428286e+00
#  -9.93126394e-01 -4.82143797e+00 -1.54796436e+01 -2.18890431e+01
#  -5.91570608e+00  1.04598136e+01  7.01431670e-03 -1.71772853e+01
#   7.92886909e+00  1.05922182e+01  4.95723000e+00  5.07320615e+00
#   4.78268641e-02 -1.34302039e+01 -6.38342862e+00 -2.35119387e+00
#  -2.79667343e+00  2.47996881e-01  3.97219610e+00 -4.05353118e+00
#   1.24435794e+01 -4.10826902e+00  2.51719317e+00  1.59671725e+00
#  -5.37010107e-01  4.89863265e-01 -3.29287454e+00  1.53512101e+00
#   2.40008298e+00 -1.28343805e-02 -5.15057694e+00 -3.39774113e+00
#   3.39773598e+00  2.65917051e+00 -1.55414511e+01  9.80106246e+00
#  -1.70475855e+01  9.97162553e+00  3.75958279e+00  1.68432522e+00
#  -1.96776822e+00  1.22240649e+00  1.34434170e+01  1.77618063e+00
#  -1.00198394e+01  1.19311132e+00  4.11629605e-01  1.46323611e+01
#  -1.00669711e+00  8.74902256e-01  3.65847113e+00 -1.72963599e+00
#   1.86486710e+01 -1.37725327e+01  7.87324416e+00  2.29849893e+00
#  -5.93391533e-01  2.94357549e+01 -2.96555864e+00 -5.31440273e+00
#   1.12595054e-01 -4.86136034e-01  6.41652340e+00 -8.35789640e-01
#  -6.17534561e-02  1.95554578e+01 -6.39491567e+00 -2.84286893e+00
#   8.15402249e+00 -3.60096396e+00 -5.45801330e+00  4.07984603e+00
#   1.18529973e+01 -2.22679595e+00 -3.05651354e+00 -4.14555853e+00
#  -5.41712060e+00  9.25300866e+00 -1.43357222e+00 -4.02233160e+00
#   1.79267285e+00  9.93539931e+00 -2.19833735e+00 -2.02446641e+01
#   2.90205965e+01 -9.92792502e+00 -6.32886769e+00 -2.72665074e-01
#  -1.94076652e+00 -2.49430666e+00  5.82760901e+00 -8.84650901e+00
#  -8.00493654e+00 -1.53587606e+00 -5.70809128e+00 -1.27403865e+00
#   1.52943016e+00 -2.28114594e+01  2.17500905e+00 -4.13002161e+00
#  -1.28822509e+01 -5.79836973e-01 -1.18315319e+00 -4.04440946e-01
#  -2.30271314e-01  1.00037873e+01 -6.25508222e+00 -9.82826987e-01
#  -8.22404702e+00 -5.43317791e-01 -1.96098233e+00 -3.68900011e+00
#  -2.50879934e+00  3.70407137e+00 -4.64621457e+00 -4.11100507e+00
#  -1.43167971e+00 -1.07992137e+01 -9.33032668e-01 -1.52898487e+00
#  -9.72500964e+00 -1.43572464e+01 -1.69971908e+01 -1.83189704e+01
#  -1.03228214e+00  6.96061622e-01  1.27109537e+00 -8.12596857e+00
#  -1.17042287e+00  2.10871140e+00 -1.24531461e+01 -5.18652161e-01
#   2.29971613e+00 -7.82381816e+00  7.57493307e+00 -6.50171977e+00
#  -9.46233326e+00  6.96516547e+00  1.14005776e+01  2.56778357e-01
#   3.70888477e+00 -2.22936969e+00 -9.36204187e+00  1.35716813e+00
#   3.93648882e+00 -3.43530952e+00  5.77179650e+00 -4.42985356e+00
#  -9.49271702e+00  9.10755596e+00  1.34449983e+01 -4.17680342e+00
#   2.02892844e+01 -2.88703036e+00  8.32967335e-01 -5.73970186e-01
#   3.98854211e+00  2.81786854e+00  8.97784747e-01 -2.13957000e+00
#  -1.69525586e+01  1.25302114e+01 -4.90932020e+00 -2.12392908e-01
#   1.37286842e+00  3.35639079e+00  2.92209696e-01 -4.17967835e+00
#  -3.46972826e+00  2.65515213e-03 -1.56051149e+00  5.20335697e-01
#  -2.52102673e-01  6.91666004e+00 -2.88181773e-01 -1.30610954e+01
#   1.38071729e+01  1.00368366e+01  2.13204358e+01 -1.33628913e+01
#  -1.22213100e+00  1.00211535e+01  5.43361323e+00  2.16682015e+00
#  -2.13384647e+01 -7.87958922e+00  3.74205316e+00  9.20748970e+00
#   4.34126657e-01  1.05097061e+01 -9.43355009e+00 -3.15202256e+00
#  -7.97740216e+00  1.09926149e-02  3.04839771e+00 -1.68803711e+00
#   2.10747178e+01  3.23468171e+00  1.39652271e+01  5.37620561e+00
#   1.67673361e+01 -6.81583776e+00  2.45665792e+00  1.30438438e+00
#   7.08082936e+00 -4.71256504e+00  2.86190638e+00  2.37278759e+00
#  -3.26027830e+00  2.96099240e+00  1.18665865e+01  3.99394483e-01
#   2.06275137e+00 -7.91400218e+00  2.85317759e+01  1.13115370e+01
#   4.56382114e+00  9.17927821e+00  5.02075633e+00  9.83606217e+00
#  -1.15953323e-01 -1.02153942e+01  3.79030061e+00  3.45952136e-01
#  -5.56818772e-03  2.36240389e+00 -5.92025214e-01  1.54623788e+01
#  -3.66815294e+00  1.13891370e-01  2.19498666e+00  3.83134322e+00
#  -6.36641144e+00  2.29543347e+00  3.95459705e+00 -1.89476027e+00
#   6.34290508e+00 -7.55605681e-01 -4.42776931e-01  3.08572483e+00
#   1.54386239e+00  1.76259109e+01  3.82088283e+00  1.41337025e+01
#  -1.79810551e+01 -9.63850036e-01 -7.92762309e+00 -5.37472921e+00
#  -1.13901422e+01  2.51353013e+00  2.90323784e+00  1.89348824e+00
#  -2.78794798e+00  2.26355626e-01 -6.23088899e+00  5.16643393e+00
#  -3.02691789e+00 -1.71655514e+00  2.62750909e+00 -8.26748278e+00
#   3.09120224e+00  9.85588775e+00  1.76019229e+00  7.41786089e+00
#  -1.02002515e+01 -2.44615613e+00  8.28503690e-01 -1.25864731e+01
#   2.91588904e+00  1.16273390e+01 -2.45075750e+01 -1.08166745e+01
#   1.32132631e+00  4.40445032e+00  8.61426831e+00  8.22891769e-01
#   1.31869942e-01  1.43337249e+00 -4.14793919e+00 -5.33098648e+00
#  -2.86609903e+00  4.65501607e-02 -5.86317934e+00 -5.36729944e+00
#  -2.89841895e-01  8.44550008e-01 -1.51977190e+00 -6.04711723e+00
#  -8.90431663e-01 -7.70484211e+00  2.97216250e+00 -3.16646032e+00
#  -1.00166006e+01 -1.77240950e+00  1.40125796e+00  5.75437463e+00
#  -5.69021367e-01 -7.90309913e+00  3.54868480e+00 -8.19710896e+00
#   6.06840216e+00 -5.34840847e+00  6.88935371e+00  8.92815029e+00
#   3.61773229e+00  7.46300531e+00 -2.82773383e+00 -5.59065449e+00
#  -1.16949656e+00 -3.45919179e+00  1.05403191e+01 -9.76975418e+00
#   5.14945660e+00  2.75636103e+00  1.28755692e+00  9.87726441e+00
#  -1.39512018e+00 -8.36982823e+00  1.45233584e+00 -2.80754909e+00
#   9.19775491e-01  7.63321435e+00 -3.86417257e+00  6.20048785e+00
#  -2.95092326e+00  3.56295888e+00 -3.69118334e-01  1.80654342e+00
#  -2.46575698e+00 -7.63315292e+00 -4.41975389e+00  7.11589018e+00
#  -3.14642278e+00 -1.09149083e+01 -3.04853130e+00 -1.33440660e+00
#  -1.44794802e+01 -9.04458418e+00 -5.40093041e+00 -1.64253722e+01
#  -8.27919404e+00 -7.35447402e+00 -1.40690370e+01  2.19048173e+00
#   1.12049970e+01  9.36383995e+00  3.52439466e+00  4.98438315e+00
#   1.02728058e+01 -5.81192763e-01  5.29376907e+00  1.16628868e+01
#  -1.52602863e+00  1.31431035e+01 -8.33800333e+00 -5.07400505e+00
#  -1.24395493e-01  4.75768017e-01 -9.61748835e+00  3.32486946e+00
#  -7.27460610e-01 -6.65483454e+00 -3.52999171e-01 -9.25240194e-01
#   9.73373582e-01 -1.21575080e+01  1.33048684e+01  5.93658891e+00
#   1.25284249e+01  3.79104221e-01  1.76802002e-01 -3.83476763e+00
#   7.24642700e+00  8.82117037e-01 -9.16706752e-01  8.78526774e+00
#   1.29244629e+01  1.26776416e+00  2.75899340e+00 -2.37538694e+00
#   1.70387437e+01 -9.74582527e+00 -7.96297930e+00  1.94113129e+00
#   6.01627539e+00  8.42507355e+00  1.92022413e+00  6.76183377e+00
#  -2.74408437e+00 -6.10388571e+00 -5.64899341e+00  1.42244490e+01
#   1.03775816e+01  3.77334535e+00  7.01838433e+00  2.26970974e+01
#   2.59087921e+00 -2.19629356e+00  1.33292968e+01  5.25932031e+00]
#
# Results for polynomial with degree 6:
# Estimated polynomial coefficients: [-1.69836273e+01  2.26954798e+01  2.64782611e-01 -3.50056090e+00
#  -9.10971524e-02  1.22603111e-01  7.36093972e-03]
# Uncertainty in estimated coefficients: [[ 1.09950077e-01 -9.70408532e-03 -1.09380306e-01  3.45730660e-03
#    2.48748724e-02 -2.63308548e-04 -1.57506957e-03]
#  [-9.70408532e-03  8.70792837e-02  1.08152885e-02 -3.32725960e-02
#   -2.24957166e-03  2.73929210e-03  1.27812830e-04]
#  [-1.09380306e-01  1.08152885e-02  1.61519515e-01 -3.29507381e-03
#   -4.15320035e-02  2.17513136e-04  2.80306503e-03]
#  [ 3.45730660e-03 -3.32725960e-02 -3.29507381e-03  1.60827728e-02
#    5.28829037e-04 -1.47131834e-03 -2.17450793e-05]
#  [ 2.48748724e-02 -2.24957166e-03 -4.15320035e-02  5.28829037e-04
#    1.16213850e-02 -2.53344755e-05 -8.28961857e-04]
#  [-2.63308548e-04  2.73929210e-03  2.17513136e-04 -1.47131834e-03
#   -2.53344755e-05  1.42353478e-04  4.62257518e-07]
#  [-1.57506957e-03  1.27812830e-04  2.80306503e-03 -2.17450793e-05
#   -8.28961857e-04  4.62257518e-07  6.14985070e-05]]
# Posterior variance factor: 0.944928427796349
# Observation residuals: [ 2.51960026e-01  8.26893943e-01 -2.16116205e+01  1.62630373e+00
#  -1.64482676e+00  2.85967517e+00  2.84257109e+00  1.73548732e+00
#   1.44239658e+00 -1.36757054e+01  3.58947162e+00 -5.14311951e+00
#   5.31909642e+00  4.72169976e+00 -5.92878249e+00  8.48159278e+00
#  -2.06558188e+00 -7.56848216e+00  2.23073598e+00 -1.31814038e+01
#  -2.99821435e-01 -4.80884651e+00 -1.04365424e+00  2.57995006e+00
#  -1.78065434e+00 -1.32538905e+00 -6.50201356e+00  2.02723831e+01
#   2.47182673e+00  2.73103740e+00  6.25717899e+00 -2.84850361e+00
#   7.01152788e+00  3.61409042e+00 -1.54422126e+01 -1.12436275e+01
#  -3.78216654e-01 -1.56449984e+01 -9.71775946e-01 -2.80952307e+00
#   1.45580506e-01  5.90129248e+00 -1.29869111e-01 -6.33515158e-01
#   4.16757923e+00 -1.09836805e+00  9.58089399e+00  4.76866677e+00
#   7.08370531e-01  1.09881267e+00  2.89187518e+01  6.93713016e+00
#   2.45419369e+01  6.20524272e+00 -2.58513446e+00 -1.99640175e+00
#  -2.17350090e+01  5.12645855e+00  3.35701372e+00 -3.16500770e+00
#  -3.55230396e+00  1.87148522e+00 -1.15949932e+01 -1.23438643e+01
#   7.82083211e+00  1.76649992e+00 -1.67571979e-01 -2.32989239e+01
#   1.23235072e+01 -5.77057716e+00  4.11061144e+00  4.68461267e+00
#  -6.88672437e+00 -2.47716706e+00  1.93229340e+01  1.27335491e-01
#  -3.21582410e+00  5.40630484e-01 -3.77234263e+00  1.09048183e+00
#  -1.56769757e-02  9.11435994e+00 -1.19943558e+00 -1.11524221e+01
#  -1.05066162e+00 -1.08020775e+00 -4.40587860e-01  5.40547441e+00
#   3.80279471e+00  3.91630037e+00 -7.80378671e+00  2.24830636e+00
#   4.66203814e+00 -3.07974435e+00 -9.61357042e-01 -1.37224815e+01
#   6.61810589e+00 -8.14772537e-01  8.32084023e+00  1.48384669e+00
#  -2.35253381e+00 -6.13931576e+00 -1.67555261e+01 -2.31224995e+01
#  -7.10633954e+00  9.31236609e+00 -1.09691728e+00 -1.82374037e+01
#   6.91282910e+00  9.62049023e+00  4.03001671e+00  4.19067952e+00
#  -7.89871097e-01 -1.42229607e+01 -7.13116079e+00 -3.05384641e+00
#  -3.45421937e+00 -3.64442951e-01  3.40483490e+00 -4.57586773e+00
#   1.19661876e+01 -4.54082156e+00  2.12934948e+00  1.25342751e+00
#  -8.35924828e-01  2.35121131e-01 -3.50366955e+00  1.36802512e+00
#   2.27641616e+00 -9.33637705e-02 -5.18828163e+00 -3.39295446e+00
#   3.44466052e+00  2.74785976e+00 -1.54113895e+01  9.97208535e+00
#  -1.68360307e+01  1.02232651e+01  4.05084270e+00  2.01472408e+00
#  -1.59872817e+00  1.62957399e+00  1.38881827e+01  2.25800025e+00
#  -9.50152481e+00  1.74734786e+00  1.00120127e+00  1.52566678e+01
#  -3.48268256e-01  1.56682793e+00  4.38325632e+00 -9.72640109e-01
#   1.94372176e+01 -1.29531060e+01  8.72287014e+00  3.17763341e+00
#   3.14551286e-01  3.03717969e+01 -2.00213522e+00 -4.32432383e+00
#   1.12859571e+00  5.55045283e-01  7.48213732e+00  2.53502250e-01
#   1.05045559e+00  2.06898174e+01 -5.23917746e+00 -1.66652911e+00
#   9.35018231e+00 -2.38576997e+00 -4.22457484e+00  5.33073579e+00
#   1.31205421e+01 -9.43395173e-01 -1.75805815e+00 -2.83285192e+00
#  -4.09096781e+00  1.05918013e+01 -8.29469633e-02 -2.66068158e+00
#   3.16453958e+00  1.13166748e+01 -8.08460599e-01 -1.88469928e+01
#   3.04252568e+01 -8.51707980e+00 -4.91263986e+00  1.14814517e+00
#  -5.16171593e-01 -1.06672202e+00  7.25739147e+00 -7.41531725e+00
#  -6.57312026e+00 -1.04216064e-01 -4.27736405e+00  1.54983948e-01
#   2.95598116e+00 -2.13881418e+01  3.59433703e+00 -2.71543379e+00
#  -1.14731477e+01  8.23043486e-01  2.12773007e-01  9.83806341e-01
#   1.14957957e+00  1.13745317e+01 -4.89414677e+00  3.67605029e-01
#  -6.88480477e+00  7.84056799e-01 -6.46144643e-01 -2.38735965e+00
#  -1.22100729e+00  4.97737322e+00 -3.38803512e+00 -2.86857036e+00
#  -2.05602050e-01 -9.59009512e+00  2.58535330e-01 -3.55548304e-01
#  -8.57027442e+00 -1.32217713e+01 -1.58815235e+01 -1.72236468e+01
#   4.21734581e-02  1.74913674e+00  2.30228960e+00 -7.11714339e+00
#  -1.84442484e-01  3.07138380e+00 -1.15142321e+01  3.96065870e-01
#   3.18981373e+00 -6.95875226e+00  8.41456937e+00 -5.68789748e+00
#  -8.67469573e+00  7.72626125e+00  1.21347886e+01  9.63775441e-01
#   4.38835310e+00 -1.57773072e+00 -8.73851850e+00  1.95230419e+00
#   4.50298043e+00 -2.89770479e+00  6.28028672e+00 -3.95069060e+00
#  -9.04307911e+00  9.52748609e+00  1.38350531e+01 -3.81677643e+00
#   2.06191465e+01 -2.58745496e+00  1.10214962e+00 -3.35271979e-01
#   4.19668076e+00  2.99538771e+00  1.04464005e+00 -2.02340732e+00
#  -1.68671017e+01  1.25849651e+01 -4.88525142e+00 -2.18975184e-01
#   1.33568472e+00  3.28867101e+00  1.94034877e-01 -4.30821144e+00
#  -3.62850717e+00 -1.86241445e-01 -1.77938198e+00  2.71650769e-01
#  -5.30427005e-01  6.60888692e+00 -6.25197537e-01 -1.34271322e+01
#   1.34123522e+01  9.61348435e+00  2.08688198e+01 -1.38424880e+01
#  -1.72941018e+00  9.48650508e+00  4.87192394e+00  1.57843322e+00
#  -2.19531911e+01 -8.52028238e+00  3.07578078e+00  8.51604012e+00
#  -2.82083695e-01  9.76916575e+00 -1.01979756e+01 -3.93987430e+00
#  -8.78820726e+00 -8.22279234e-01  2.19315934e+00 -2.56472831e+00
#   2.01771008e+01  2.31667897e+00  1.30273918e+01  4.41910359e+00
#   1.57915459e+01 -7.80972517e+00  1.44527647e+00  2.76124126e-01
#   6.03631735e+00 -5.77269011e+00  1.78681833e+00  1.28339785e+00
#  -4.36329749e+00  1.84502673e+00  1.07383678e+01 -7.40373504e-01
#   9.12147775e-01 -9.07471793e+00  2.73616809e+01  1.01328048e+01
#   3.37720294e+00  7.98553365e+00  3.82065348e+00  8.63037717e+00
#  -1.32643656e+00 -1.14298843e+01  2.57260224e+00 -8.74149141e-01
#  -1.22726047e+00  1.13993869e+00 -1.81443938e+00  1.42408452e+01
#  -4.88797152e+00 -1.10337268e+00  9.81120996e-01  2.62172390e+00
#  -7.57093276e+00  1.09686513e+00  2.76283961e+00 -3.07884634e+00
#   5.16735300e+00 -1.92175943e+00 -1.59866665e+00  1.94096573e+00
#   4.11101005e-01  1.65060143e+01  2.71471791e+00  1.30421351e+01
#  -1.90571603e+01 -2.02363012e+00 -8.97021736e+00 -6.39927962e+00
#  -1.23957939e+01  1.52762845e+00  1.93793328e+00  9.49623285e-01
#  -3.70953595e+00 -6.72123628e-01 -7.10543397e+00  4.31664212e+00
#  -3.85114488e+00 -2.51441339e+00  1.85681517e+00 -9.01022561e+00
#   2.37718783e+00  9.17136911e+00  1.10592622e+00  6.79459304e+00
#  -1.07917872e+01 -3.00523804e+00  3.02584251e-01 -1.30785349e+01
#   2.45836588e+00  1.12050207e+01 -2.48940376e+01 -1.11666465e+01
#   1.00846306e+00  4.12929655e+00  8.37740684e+00  6.24886724e-01
#  -2.67338593e-02  1.31469473e+00 -4.22618682e+00 -5.36832127e+00
#  -2.86206040e+00  9.23999984e-02 -5.77510404e+00 -5.23660867e+00
#  -1.16170652e-01  1.06154102e+00 -1.25914832e+00 -5.74257549e+00
#  -5.41714178e-01 -7.31172005e+00  3.40988841e+00 -2.68396158e+00
#  -9.48919125e+00 -1.19998352e+00  2.01877371e+00  6.41701981e+00
#   1.38758531e-01 -7.15021443e+00  4.34660834e+00 -7.35424941e+00
#   6.95605714e+00 -4.41613724e+00  7.86602255e+00  9.94895773e+00
#   4.68237810e+00  8.57114713e+00 -1.67648141e+00 -4.39672080e+00
#   6.66442053e-02 -2.18136394e+00  1.18592673e+01 -8.41029990e+00
#   6.54875394e+00  4.19478889e+00  2.76435223e+00  1.13916126e+01
#   1.55913810e-01 -6.78302898e+00  3.07392533e+00 -1.15219987e+00
#   2.60779744e+00  9.35276450e+00 -2.11429730e+00  7.97942556e+00
#  -1.14424643e+00  5.39598983e+00  1.48881896e+00  3.68787545e+00
#  -5.62606727e-01 -5.70982697e+00 -2.47796187e+00  9.07437044e+00
#  -1.17310145e+00 -8.92866353e+00 -1.05135220e+00  6.71644887e-01
#  -1.24666921e+01 -7.02727026e+00 -3.38137765e+00 -1.44059450e+01
#  -6.26233522e+00 -5.34270626e+00 -1.20649639e+01  4.18417447e+00
#   1.31855402e+01  1.13283800e+01  5.46999201e+00  6.90801118e+00
#   1.21713495e+01  1.28906221e+00  7.13243987e+00  1.34665859e+01
#   2.39217811e-01  1.48663216e+01 -6.66048529e+00 -3.44595613e+00
#   1.45031657e+00  1.99317548e+00 -8.16145458e+00  4.71535776e+00
#   5.93206363e-01 -5.40837016e+00  8.14774519e-01  1.59246537e-01
#   1.96986749e+00 -1.12538237e+01  1.41108137e+01  6.63975208e+00
#   1.31236476e+01  8.61111368e-01  5.40200333e-01 -3.59549100e+00
#   7.35594795e+00  8.56125760e-01 -1.08409088e+00  8.47048457e+00
#   1.24561474e+01  6.39654569e-01  1.96469772e+00 -3.34239233e+00
#   1.58923718e+01 -1.10783552e+01 -9.48859521e+00  2.15363662e-01
#   4.08315080e+00  6.27724569e+00 -4.49796000e-01  4.16198811e+00
#  -5.58153473e+00 -9.18686749e+00 -8.98558250e+00  1.06260259e+01
#   6.50894525e+00 -3.74037684e-01  2.58356543e+00  1.79659958e+01
#  -2.44551093e+00 -7.54713925e+00  7.65466597e+00 -7.48589687e-01]
#
# Posterior Variance Factor for Each Polynomial:
# Posterior variance factor for degree 2 = 12.072979326943319
# Posterior variance factor for degree 4 = 1.1441867042253173
# Posterior variance factor for degree 6 = 0.944928427796349
#
# Norms of Weighted Equations:
# Norm for Quadratic function: 230.80021355007958
# Norm for Quartic function: 36.255545804535174
# Norm for Hexic function: 6.553038055128298

# %%
# step 14
# Compare the results of a posterier variance factor and norm from unweighted LSE and weighted LSE, what phenomena do you observe? Explain this phenomena.
# (2 marks)

# When weights are included in LSE, observations that are more precise and reliable will be weighted heaver, meaning that they will contribute more to the solution.
# The posterior variance factor essentially tells us how large residuals are. When accounting for weights, this value should decrease, as seen in our results.
# The norms should also decrease when more reliable points contribute more, as seen in our results.
# When comparing the unweighted and weighted results, the weighted ones give us a smaller posterior variance factor and norm. 
# This is because weighted LSE will generate a curve that passes closer to the more reliable points. On the other hand, unweighted LSE gives equal importance to all points,including the less reliable ones, which may lead to greater variance
# This can create a better representation of the data as not all data points are created equally. Some are better measurements than others, and thus allowing better data points to contribute more to our calculations can generate a more accurate function.
# The weighted model better accounts for the noisy/ variable data, which allows it to better capture the pattern in the dataset and generate a more accurate curve.
